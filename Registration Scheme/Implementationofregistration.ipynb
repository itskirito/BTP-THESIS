# %% [markdown]
# **REGITRATION SCHEME CODE:**
# Based on computation, SHA-256 is generally considered more computationally intensive compared to SHA-1. SHA-256 belongs to the SHA-2 family of hash functions, which provides a higher level of security and larger hash output (256 bits) compared to SHA-1.
#
# In terms of computational performance, SHA-1 is faster than SHA-256 because it operates on smaller hash output (160 bits) and has simpler operations. However, SHA-1 is considered weak and vulnerable to collision attacks, which means it may not provide the same level of security as SHA-256.
#
# Therefore, if computational efficiency is a primary concern and the security requirements can be adequately met by SHA-1, it might be preferred due to its faster computation. However, if stronger security is required, SHA-256 is generally recommended, even though it may be computationally more expensive.
#
# It's important to note that the choice of algorithm should also consider the specific security requirements, the potential for future attacks, and compliance with industry standards or regulations. In general, for modern applications, it is recommended to use SHA-256 or higher for stronger security guarantees, even if it comes at a slightly higher computational cost.

# %% [markdown]
# **FOR A LOW STRENGTH KEY, WE WILL TAKE A 512 BITS KEY SIZE.**

# %%
import hashlib
import os

class UDCSystem:
    def __init__(self):
        self.evs = {}
        self.css = {}
        self.rsus = {}
        self.revocation_list = set()

    def register_ev(self, ev_name, ev_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(ev_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if EV identity exists in the database or revocation list
        if ev_name in self.evs:
            return "Registration failed. EV identity already registered."
        if ev_name in self.revocation_list:
            return "Registration failed. EV identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, ev_name)

        # Step 6: Store EV information
        self.evs[ev_name] = {
            "public_key": public_key,
            "pseudo_identity": pseudo_identity
        }

        return f"{ev_name} registration successful.\nPublic Key: {public_key}\nPrivate Key: {private_key}\nPseudo-Identity: {pseudo_identity}"

    def register_cs(self, cs_name, cs_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(cs_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if CS identity exists in the database or revocation list
        if cs_name in self.css:
            return "Registration failed. CS identity already registered."
        if cs_name in self.revocation_list:
            return "Registration failed. CS identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, cs_name)

        # Step 6: Store CS information
        self.css[cs_name] = {
            "public_key": public_key,
            "pseudo_identity": pseudo_identity
        }

        return f"{cs_name} registration successful.\nPublic Key: {public_key}\nPrivate Key: {private_key}\nPseudo-Identity: {pseudo_identity}"

    def register_rsu(self, rsu_name, rsu_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(rsu_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if RSU identity exists in the database or revocation list
        if rsu_name in self.rsus:
            return "Registration failed. RSU identity already registered."
        if rsu_name in self.revocation_list:
            return "Registration failed. RSU identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, rsu_name)

        # Step 6: Store RSU information
        self.rsus[rsu_name] = {
            "public_key": public_key,
            "pseudo_identity": pseudo_identity
        }

        return f"{rsu_name} registration successful.\nPublic Key: {public_key}\nPrivate Key: {private_key}\nPseudo-Identity: {pseudo_identity}"

    def _is_within_execution_range(self, timestamp):
        # Adjust the execution range logic according to your requirements
        return True

    def _generate_key_pair(self):
        # Generate a 512-bit private key
        private_key = os.urandom(64).hex()

        # Calculate public key by hashing the private key
        public_key = hashlib.sha256(private_key.encode()).hexdigest()

        return public_key, private_key

    def _calculate_pseudo_identity(self, private_key, identity):
        # Use a secure hash function, such as SHA-256, to calculate the pseudo-identity
        hash_input = private_key.encode() + identity.encode()
        pseudo_identity = hashlib.sha256(hash_input).hexdigest()
        return pseudo_identity

# Example usage
udc_system = UDCSystem()

# EV registration
ev_names = ["EV1", "EV2", "EV3"]
ev_timestamp = "2023-06-28T12:00:00"

for ev_name in ev_names:
    ev_registration_result = udc_system.register_ev(ev_name, ev_timestamp)
    print(ev_registration_result)

# CS registration
cs_names = ["CS1", "CS2", "CS3"]
cs_timestamp = "2023-06-28T12:00:00"

for cs_name in cs_names:
    cs_registration_result = udc_system.register_cs(cs_name, cs_timestamp)
    print(cs_registration_result)

# RSU registration
rsu_names = ["RSU1", "RSU2", "RSU3"]
rsu_timestamp = "2023-06-28T12:00:00"

for rsu_name in rsu_names:
    rsu_registration_result = udc_system.register_rsu(rsu_name, rsu_timestamp)
    print(rsu_registration_result)
# Out:
# EV1 registration successful.
# Public Key: 7ce1a0de01379ccd99eedb958be9d2c1c014a116312fba43473a3f2ad89ba54a
# Private Key: 2c6514fc0f03ee43e4565c1a8aa23426248f3a67ec7ed7855cac948a275184e072c0aec6f9135891c0c2ed64775540cdd80fc4c6e73444d6bf0d228d338b28f0
# Pseudo-Identity: db8907219028ee22dece8355be6ee88caaec0042a362e7b92ca69681b097acb2
# EV2 registration successful.
# Public Key: cc7367f8ccf47f4418fac0ee55554fe2b2043e606d480935ab30fd3eb8ae47a4
# Private Key: 2834d3b68a76d36e72274c302880e55ebd2b3642e4f0aeff016ccca6c3174251edd1c110c76edb98d11de35106a759b58481e7d5fcb1cb2d3d49f77d316d75e4
# Pseudo-Identity: c5312bed67081ce78b20d64ede6bc7c8868c39a46932ee9a31cab01f851fc972
# EV3 registration successful.
# Public Key: 42d185b6afba55fcfa1927a7190cc2cd0ff5cce11e7ddd041cf9fb7fa66dd917
# Private Key: 94cacd8770f07131e85d3ba38622e69faa651c68f3e253369e1e285098b01b15a3614d04ce50a275a11e8388c894c35a0f55c9341be02e28b44a6260f4c33439
# Pseudo-Identity: d73325fca5fa4f24f938c1fa832cc43b5571561d8add1a87187b97e09093bc93
# CS1 registration successful.
# Public Key: d1f18bc3ca1d9d8ec273c949bd4d37c062d5ec9a50db414a1af3da9b22196f2d
# Private Key: 4609eee5875c370420ebab9fe9f58475e0db5ce93fbede1b6b7f5f454b3123b489b5bbd5d2406435d79e0849f9513bdb4ebf38881276edc06b02da5e62147baa
# Pseudo-Identity: 00b75b649f6f0c3b0a5039b07739a4df536fdcf7bd047680ae5841b814ff0a2b
# CS2 registration successful.
# Public Key: 913edf6356efab1b73f56697c34cdc04b27a892ea8158030be1b8578bc30b2c3
# Private Key: 5219273d1349bc7374dbcf3560a39b3d973af6e5d021629d87870b70879b72d4555cacdfb7018d673fa1b05a34ef3a3980d9d55c76225f720713c6747b8d268c
# Pseudo-Identity: 982a62dc443c54f4076be5f1d9718ba2b3a1dcbdec94bacfe4ae5d0a293565a5
# CS3 registration successful.
# Public Key: a499d488aba415f9c1b02851523c8b2f5277d79690689d66541bfb8f33b81101
# Private Key: ac4875eb5373c9a689241dd4f3335029e9e105bb6c0ff2777c02ce92bb371cb7ce90de830ea29ffc2ce9c32fd225492853792c5c2a2cadeea9841704236941a0
# Pseudo-Identity: 3efb1d84fa97203b66b685ec3df8f5ed59187d0f1f54bb40d616c8275c290b23
# RSU1 registration successful.
# Public Key: 24aa950676e0d0cd79554e6cc39c47bb4fe178ba4fd990c7b85df7d61b4224fc
# Private Key: a43e8b2dbbc20927387139193f9fd70f45959f857d246df13c7df10be3728605b40a1d1bb1156a971530edcbdacc346471f9366a3eb5f297c31141010b4a4fb8
# Pseudo-Identity: aaac475bef9c0e88248c8c2afa2d3c9c950fd86bfd54d044c4757373b35382ed
# RSU2 registration successful.
# Public Key: 8c2e596aa1d67a819a663388dc573e28e48709b7b6543e81077ee9914bc862bf
# Private Key: 5efd237494291c88c8628e03ecb04b403d7dfdf7d84f59a19394621d2b5eded395253fe9d6ebb661da8c59f42cd97ffc26446f7481259326bc4c9704cbf30d1d
# Pseudo-Identity: 3d2576889a7c52eb2858484973985afe2da8e05fe803db694a01cbf050e56316
# RSU3 registration successful.
# Public Key: b9fefc2b0f6c6546b364f897eea8108a4e9fe7e956a3d62b70fa1366f6969cef
# Private Key: 0e5be0ef544fddddd735164ce3581d3ca2eb17e1404ed2592e1855ebd5bb6b54086819146091fd95b81ada98d0cee74ad98a0c4dea9a37144e3b80cde0fbfb34
# Pseudo-Identity: eb579aed699f0b77e78aa5c931084f316f72387d0ab44a0fa033cac352134d12

# %% [markdown]
# **NOW WE WILL TAKE THE KEYS PAIRS SIZE TO BE 1028 BITS, WHICH ARE Medium-strength keys.**

# %%
import hashlib
import os

class UDCSystem:
    def __init__(self):
        self.evs = {}
        self.css = {}
        self.rsus = {}
        self.revocation_list = set()

    def register_ev(self, ev_name, ev_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(ev_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if EV identity exists in the database or revocation list
        if ev_name in self.evs:
            return "Registration failed. EV identity already registered."
        if ev_name in self.revocation_list:
            return "Registration failed. EV identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, ev_name)

        # Step 6: Store EV information
        self.evs[ev_name] = {
            "public_key": public_key,
            "pseudo_identity": pseudo_identity
        }

        return f"{ev_name} registration successful.\nPublic Key: {public_key}\nPrivate Key: {private_key}\nPseudo-Identity: {pseudo_identity}"

    def register_cs(self, cs_name, cs_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(cs_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if CS identity exists in the database or revocation list
        if cs_name in self.css:
            return "Registration failed. CS identity already registered."
        if cs_name in self.revocation_list:
            return "Registration failed. CS identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, cs_name)

        # Step 6: Store CS information
        self.css[cs_name] = {
            "public_key": public_key,
            "pseudo_identity": pseudo_identity
        }

        return f"{cs_name} registration successful.\nPublic Key: {public_key}\nPrivate Key: {private_key}\nPseudo-Identity: {pseudo_identity}"

    def register_rsu(self, rsu_name, rsu_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(rsu_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if RSU identity exists in the database or revocation list
        if rsu_name in self.rsus:
            return "Registration failed. RSU identity already registered."
        if rsu_name in self.revocation_list:
            return "Registration failed. RSU identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, rsu_name)

        # Step 6: Store RSU information
        self.rsus[rsu_name] = {
            "public_key": public_key,
            "pseudo_identity": pseudo_identity
        }

        return f"{rsu_name} registration successful.\nPublic Key: {public_key}\nPrivate Key: {private_key}\nPseudo-Identity: {pseudo_identity}"

    def _is_within_execution_range(self, timestamp):
        # Adjust the execution range logic according to your requirements
        return True

    def _generate_key_pair(self):
        # Generate a 1024-bit private key
        private_key = os.urandom(128).hex()

        # Calculate public key by hashing the private key
        public_key = hashlib.sha256(private_key.encode()).hexdigest()

        return public_key, private_key

    def _calculate_pseudo_identity(self, private_key, identity):
        # Use a secure hash function, such as SHA-256, to calculate the pseudo-identity
        hash_input = private_key.encode() + identity.encode()
        pseudo_identity = hashlib.sha256(hash_input).hexdigest()
        return pseudo_identity

# Example usage
udc_system = UDCSystem()

# EV registration
ev_names = ["EV1", "EV2", "EV3"]
ev_timestamp = "2023-06-28T12:00:00"

for ev_name in ev_names:
    ev_registration_result = udc_system.register_ev(ev_name, ev_timestamp)
    print(ev_registration_result)

# CS registration
cs_names = ["CS1", "CS2", "CS3"]
cs_timestamp = "2023-06-28T12:00:00"

for cs_name in cs_names:
    cs_registration_result = udc_system.register_cs(cs_name, cs_timestamp)
    print(cs_registration_result)

# RSU registration
rsu_names = ["RSU1", "RSU2", "RSU3"]
rsu_timestamp = "2023-06-28T12:00:00"

for rsu_name in rsu_names:
    rsu_registration_result = udc_system.register_rsu(rsu_name, rsu_timestamp)
    print(rsu_registration_result)
# Out:
# EV1 registration successful.
# Public Key: 902876e1321012660de641f3089e56d89675cb1073dea111b1339b2a8f3c3710
# Private Key: 
# Pseudo-Identity: 3c2b2f8b65fcb9c3c23ea8abb434ce36f6ce83f02cbcc487a843b7770093189e
# EV2 registration successful.
# Public Key: c2479163d6b3dd3d781149d5569a7127b4370051fd3189867c1d48d0718a29d2
# Private Key: 
# Pseudo-Identity: 22bb25b62d0478973b2d1607f1a866b47ad70e3ab7572547266009766026e122
# EV3 registration successful.
# Public Key: 3d59f63b9834105b286821827b1317e2f726eae9f69de9adf0215f4b7bdce652
# Private Key: 
# Pseudo-Identity: 2877108632d14d81bf67af9ece601c9de0e0446f0b9f48bec566641ed0e4af2d
# CS1 registration successful.
# Public Key: 6766c9a5a356059d73e52bd499c90c284ee9cd70a1cd19a0ac0ce1ee44c7f3d0
# Private Key: 
# Pseudo-Identity: e95d2a0cf5edd280ad182c68c96487a57e838683168a09ce9e848d986a26407e
# CS2 registration successful.
# Public Key: c0ef0566c69d9bed12740b898e69d45d0b02960381af94ce675a9bd6aaaa248a
# Private Key: 
# Pseudo-Identity: 392b00da2ad72f56ead2dbec98cc5f79e586a6f9d7d1f63d93f0872057ffbd28
# CS3 registration successful.
# Public Key: b2aad2fa18c4055fe25dae704eb15077ac3ef41d413a51eae32d0ef6d2ed72b7
# Private Key: 
# Pseudo-Identity: bb9b4f8b6720cdd210ae7e709f17c4e114d93722831a3ee27e3ab4ece01c690d
# RSU1 registration successful.
# Public Key: 9c29b6bfc39335e4011558805519d9ede954db0221e42feec85cf3ff205d749c
# Private Key: 
# Pseudo-Identity: d800c5fa23a61a01613ccb78dfe32b5ee8a8b04c4f57592a42cf09ebbefa25d9
# RSU2 registration successful.
# Public Key: 7e6ac4f30ba9dbeb6bb825032c1c0fa5c7b9ea4458a57ca02f431bc95115adbb
# Private Key: 
# Pseudo-Identity: c94c91861b5c9d213a591b439847f3977dff4f6a0be41274ae7afe69c6599350
# RSU3 registration successful.
# Public Key: e44fdc3852c75f4bd7e60b864604fa81636bbf83d169796bc876fa11dcc14e83
# Private Key: 
# Pseudo-Identity: 6573ff660c5e4f1a9108ea1c957102c976ef2c81b741f5d1feed97141067472f

# %% [markdown]
# **IN THIS THE KEYS SIZE IS TAKE 2048 BITS. High-strength key**

# %%
import hashlib
import os

class UDCSystem:
    def __init__(self):
        self.evs = {}
        self.css = {}
        self.rsus = {}
        self.revocation_list = set()

    def register_ev(self, ev_name, ev_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(ev_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if EV identity exists in the database or revocation list
        if ev_name in self.evs:
            return "Registration failed. EV identity already registered."
        if ev_name in self.revocation_list:
            return "Registration failed. EV identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, ev_name)

        # Step 6: Store EV information
        self.evs[ev_name] = {
            "public_key": public_key,
            "pseudo_identity": pseudo_identity
        }

        return f"{ev_name} registration successful.\nPublic Key: {public_key}\nPrivate Key: {private_key}\nPseudo-Identity: {pseudo_identity}"

    def register_cs(self, cs_name, cs_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(cs_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if CS identity exists in the database or revocation list
        if cs_name in self.css:
            return "Registration failed. CS identity already registered."
        if cs_name in self.revocation_list:
            return "Registration failed. CS identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, cs_name)

        # Step 6: Store CS information
        self.css[cs_name] = {
            "public_key": public_key,
            "pseudo_identity": pseudo_identity
        }

        return f"{cs_name} registration successful.\nPublic Key: {public_key}\nPrivate Key: {private_key}\nPseudo-Identity: {pseudo_identity}"

    def register_rsu(self, rsu_name, rsu_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(rsu_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if RSU identity exists in the database or revocation list
        if rsu_name in self.rsus:
            return "Registration failed. RSU identity already registered."
        if rsu_name in self.revocation_list:
            return "Registration failed. RSU identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, rsu_name)

        # Step 6: Store RSU information
        self.rsus[rsu_name] = {
            "public_key": public_key,
            "pseudo_identity": pseudo_identity
        }

        return f"{rsu_name} registration successful.\nPublic Key: {public_key}\nPrivate Key: {private_key}\nPseudo-Identity: {pseudo_identity}"

    def _is_within_execution_range(self, timestamp):
        # Adjust the execution range logic according to your requirements
        return True

    def _generate_key_pair(self):
        # Generate a 2048-bit private key
        private_key = os.urandom(256).hex()

        # Calculate public key by hashing the private key
        public_key = hashlib.sha256(private_key.encode()).hexdigest()

        return public_key, private_key

    def _calculate_pseudo_identity(self, private_key, identity):
        # Use a secure hash function, such as SHA-256, to calculate the pseudo-identity
        hash_input = private_key.encode() + identity.encode()
        pseudo_identity = hashlib.sha256(hash_input).hexdigest()
        return pseudo_identity

# Example usage
udc_system = UDCSystem()

# EV registration
ev_names = ["EV1", "EV2", "EV3"]
ev_timestamp = "2023-06-28T12:00:00"

for ev_name in ev_names:
    ev_registration_result = udc_system.register_ev(ev_name, ev_timestamp)
    print(ev_registration_result)

# CS registration
cs_names = ["CS1", "CS2", "CS3"]
cs_timestamp = "2023-06-28T12:00:00"

for cs_name in cs_names:
    cs_registration_result = udc_system.register_cs(cs_name, cs_timestamp)
    print(cs_registration_result)

# RSU registration
rsu_names = ["RSU1", "RSU2", "RSU3"]
rsu_timestamp = "2023-06-28T12:00:00"

for rsu_name in rsu_names:
    rsu_registration_result = udc_system.register_rsu(rsu_name, rsu_timestamp)
    print(rsu_registration_result)
# Out:
# EV1 registration successful.
# Public Key: 27fb39eebe1de4182435aec2e93f3cca32e12c34714c50bb1f8860634e47229e
# Private Key: ...
# Pseudo-Identity: 5b20232405547fedc3b13cd42e911cb173393a55c2ace2437da34821638baabc
# EV2 registration successful.
# Public Key: b5144cc8c902537aac32ec7277a57db83e5dd40a14b2b8aefe9df0b86ecea98a
# Private Key: ...
# Pseudo-Identity: da75c0b2e112e9e42d15399054af95799b8c873d7f17da7c9d2fd0635a78eef0
# EV3 registration successful.
# Public Key: 4d213a85945cbe3baa8b88ac8780623c08a1a1a7db512e03aec943cca060a376
# Private Key: ...
# Pseudo-Identity: 4473da3aa2792c082508b8753017d3783989f4ab9c71f67eefbfdc2fa801cc61
# CS1 registration successful.
# Public Key: cd347da30aa95fb8d596125178ef9e2859628156af15920f0c85885e996d948a
# Private Key: ...
# Pseudo-Identity: 4de21fc39a2be1bfb4cec3a69d9f3b3a44a4c961b95d208cf4e4cf6951f2942f
# CS2 registration successful.
# Public Key: bff5ace7e390833a1517387d6461a71bbc38333525087efd637def5e3249c679
# Private Key: ...
# Pseudo-Identity: f4fc5a53f067cc7e93889f90b7dfac3db89ae07f25c7b91bba9e10393839a89b
# CS3 registration successful.
# Public Key: 57ade6ee5afa5f7ae2433c0f492ac44ab93aea10d7bfdb28759ddfc5ad43f6f6
# Private Key: ...
# Pseudo-Identity: 3e9de2552770bd2c73b988a5cbe0e0d522520b5568482cbf95a15f9a2f60715b
# RSU1 registration successful.
# Public Key: f9482f163b16bdbacc0de2eb4c98710979837011ba9539531fc4c8d7a6b20553
# Private Key: ...
# Pseudo-Identity: 44562b3278b6cc5c2fe9d7ddb2acf1244cb86d8c42ea652b4330d45806951904
# RSU2 registration successful.
# Public Key: bc94d9149e41164e2ca015f02b35663ed09007334926c39d4993726696378390
# Private Key: ...
# Pseudo-Identity: 7c946601e2f55955bfbebe7525986cac939e29f175a1bab52caebfd33c8017a9
# RSU3 registration successful.
# Public Key: b5e2da86b69b2a0e1558c060641cfc73cfc46060f47232ca39ab4078bd4b2ed6
# Private Key: ...
# Pseudo-Identity: 8d05aa39a5c77c12d1e7f8e2d37bf59a1f0d41d8bcdb1cf29125db41eb4bbd0d

# %% [markdown]
# NOW HERE, We will compare the security aspects based upon the 512, 1024, 2048 BITS (OR, 64, 128, 254 bytes in hexadecimal) keys pairs.

# %%
import hashlib
import os

class UDCSystem:
    def __init__(self):
        self.evs = {}
        self.css = {}
        self.rsus = {}
        self.revocation_list = set()

    def register_ev(self, ev_name, ev_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(ev_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if EV identity exists in the database or revocation list
        if ev_name in self.evs:
            return "Registration failed. EV identity already registered."
        if ev_name in self.revocation_list:
            return "Registration failed. EV identity is illegal."

        # Step 4: Generate key pairs
        key_pairs = self._generate_key_pairs()

        # Step 5: Calculate pseudo-identities
        pseudo_identities = self._calculate_pseudo_identities(key_pairs, ev_name)

        # Step 6: Store EV information
        self.evs[ev_name] = {
            "key_pairs": key_pairs,
            "pseudo_identities": pseudo_identities
        }

        return f"{ev_name} registration successful.\nKey Pairs:\n{self._format_key_pairs(key_pairs)}\nPseudo-Identities:\n{self._format_pseudo_identities(pseudo_identities)}"

    def register_cs(self, cs_name, cs_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(cs_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if CS identity exists in the database or revocation list
        if cs_name in self.css:
            return "Registration failed. CS identity already registered."
        if cs_name in self.revocation_list:
            return "Registration failed. CS identity is illegal."

        # Step 4: Generate key pairs
        key_pairs = self._generate_key_pairs()

        # Step 5: Calculate pseudo-identities
        pseudo_identities = self._calculate_pseudo_identities(key_pairs, cs_name)

        # Step 6: Store CS information
        self.css[cs_name] = {
            "key_pairs": key_pairs,
            "pseudo_identities": pseudo_identities
        }

        return f"{cs_name} registration successful.\nKey Pairs:\n{self._format_key_pairs(key_pairs)}\nPseudo-Identities:\n{self._format_pseudo_identities(pseudo_identities)}"

    def register_rsu(self, rsu_name, rsu_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(rsu_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if RSU identity exists in the database or revocation list
        if rsu_name in self.rsus:
            return "Registration failed. RSU identity already registered."
        if rsu_name in self.revocation_list:
            return "Registration failed. RSU identity is illegal."

        # Step 4: Generate key pairs
        key_pairs = self._generate_key_pairs()

        # Step 5: Calculate pseudo-identities
        pseudo_identities = self._calculate_pseudo_identities(key_pairs, rsu_name)

        # Step 6: Store RSU information
        self.rsus[rsu_name] = {
            "key_pairs": key_pairs,
            "pseudo_identities": pseudo_identities
        }

        return f"{rsu_name} registration successful.\nKey Pairs:\n{self._format_key_pairs(key_pairs)}\nPseudo-Identities:\n{self._format_pseudo_identities(pseudo_identities)}"

    def _is_within_execution_range(self, timestamp):
        # Adjust the execution range logic according to your requirements
        return True

    def _generate_key_pairs(self):
        # Generate key pairs with different bit lengths
        key_pairs = []
        bit_lengths = [512, 1024, 2048]

        for bit_length in bit_lengths:
            # Generate a random key pair
            private_key = self._generate_private_key(bit_length)
            public_key = self._derive_public_key(private_key)

            # Add the key pair to the list
            key_pairs.append((public_key, private_key))

        return key_pairs

    def _generate_private_key(self, bit_length):
        # Generate a random private key with the specified bit length
        private_key = os.urandom(bit_length // 8)
        return private_key

    def _derive_public_key(self, private_key):
        # Derive the public key from the private key
        hash_input = hashlib.sha256(private_key).digest()
        public_key = hashlib.sha256(hash_input).digest()
        return public_key

    def _calculate_pseudo_identities(self, key_pairs, identity):
        # Calculate pseudo-identities for each key pair
        pseudo_identities = []

        for public_key, private_key in key_pairs:
            # Use a secure hash function, such as SHA-256, to calculate the pseudo-identity
            hash_input = private_key + identity.encode()
            pseudo_identity = hashlib.sha256(hash_input).hexdigest()
            pseudo_identities.append(pseudo_identity)

        return pseudo_identities

    def _format_key_pairs(self, key_pairs):
        # Format key pairs for display
        formatted_key_pairs = ""
        for i, (public_key, private_key) in enumerate(key_pairs):
            formatted_key_pairs += f"Key Pair {i + 1}:\nPublic Key: {public_key.hex()}\nPrivate Key: {private_key.hex()}\n\n"
        return formatted_key_pairs

    def _format_pseudo_identities(self, pseudo_identities):
        # Format pseudo-identities for display
        formatted_pseudo_identities = ""
        for i, pseudo_identity in enumerate(pseudo_identities):
            formatted_pseudo_identities += f"Pseudo-Identity {i + 1}: {pseudo_identity}\n"
        return formatted_pseudo_identities

# Example usage
udc_system = UDCSystem()

# EV registration
ev_names = ["EV1", "EV2", "EV3"]
ev_timestamp = "2023-06-28T12:00:00"

for ev_name in ev_names:
    ev_registration_result = udc_system.register_ev(ev_name, ev_timestamp)
    print(ev_registration_result)

# CS registration
cs_names = ["CS1", "CS2", "CS3"]
cs_timestamp = "2023-06-28T12:00:00"

for cs_name in cs_names:
    cs_registration_result = udc_system.register_cs(cs_name, cs_timestamp)
    print(cs_registration_result)

# RSU registration
rsu_names = ["RSU1", "RSU2", "RSU3"]
rsu_timestamp = "2023-06-28T12:00:00"

for rsu_name in rsu_names:
    rsu_registration_result = udc_system.register_rsu(rsu_name, rsu_timestamp)
    print(rsu_registration_result)
# Out:
# EV1 registration successful.
# Key Pairs:
# Key Pair 1:
# Public Key: 7585d191452071804f67057f257da94e1d2c40cae1a4851acf25038683122fd4
# Private Key: ca47c8884fd1cacc9ec18209071eafff66dd579413a9f21e14f3342099bc9e55b56a4c7ed45d8ea0e7d717923f2a34722e61414232898d8c9e7d7f0cec4be10f
#
# Key Pair 2:
# Public Key: 1376455ae4dc0d7ce891b79dc5faa3d1b3d69e57cf8a4891ddcd47d67da77c29
# Private Key: 
#
# Key Pair 3:
# Public Key: 2d338aec52e24c53e2c6cae4e790d6a474b4e602648fe0f63f98dc26e0429c6b
# Private Key: ...
#
#
# Pseudo-Identities:
# Pseudo-Identity 1: d2ce48ccf5ebc008ab890067a713f51fe8e003a43c73c3174b309273a7d7257a
# Pseudo-Identity 2: 075f8ca631c3387a1d6a8e9ebdfb96a4307b0501954194a89930cdbaef5ae675
# Pseudo-Identity 3: 94b318ffbf4003783b915b45951fade77630fa35be1e9af325418ab3d231ba10
#
# EV2 registration successful.
# Key Pairs:
# Key Pair 1:
# Public Key: 7a38fe8b5ead866b8cbde2c3d0d98dbecf58a8d698f9a329fe489b914302ba5e
# Private Key: 70ac7fc26a0f0a27e7bd65454fc5d06750643cac4ff1e44177bf6743cf3d1a670a640b38bcc082ed4baae7baff35c0c6058564c48b34be4bcdf558b9e833df87
#
# Key Pair 2:
# Public Key: 6049c6aa8d4b405ec48f2592354de43d48695de3c4703ff20e7d74cc5a9bfbca
# Private Key: 
#
# Key Pair 3:
# Public Key: 0540d8f2783480beaa279b7d3a16b7fccbc6d749415125f372edc08d6edbc236
# Private Key: ...
#
#
# Pseudo-Identities:
# Pseudo-Identity 1: 1584c0bd70848ec5ec6de01db66b0c45eeadc1911f1a798c8c6b6fc17195f5b5
# Pseudo-Identity 2: a820001fbe752b8643bb11071478ec4a113ad1c687444db0f03d1ad07fab9407
# Pseudo-Identity 3: daf4362e033901a96ca81217b449a8355e57a1c4f1025019b0015d9254c01615
#
# EV3 registration successful.
# Key Pairs:
# Key Pair 1:
# Public Key: 0d83e3bf579596174b005b96c2513f4a39728d037d6ac258f00666785f9dc036
# Private Key: c0ff14b97eb985129658d07f3d050de46e2708d75f42a83ea2816a3359debcbd4641b3cfb6a264edd1a28418ae3735a3b20e6e8728e27c86ea1c272394e29345
#
# Key Pair 2:
# Public Key: 8c1d9040ee2f900d26abffc4d51108fe180f4a9af81145a4a37cc481533ace67
# Private Key: 
#
# Key Pair 3:
# Public Key: ba1bdfe1d44dde75b8a654f96eefb765962d4b84fb8e3a110539e23b65f5a702
# Private Key: ...
#
#
# Pseudo-Identities:
# Pseudo-Identity 1: 48dc1e9fbcfc7ab92afcda63742569dfdb500a4e2b193a924753c3fe70df2c4e
# Pseudo-Identity 2: 14f1e5e2f6c1dc9b9b585d40d259bcfdfff3645f9c22d6a0df5f9cffd362c143
# Pseudo-Identity 3: 307166c659f8aed162d8ba529307d7a465d3a1bbf8b6c707a7a9db2ae6c426a3
#
# CS1 registration successful.
# Key Pairs:
# Key Pair 1:
# Public Key: 4f5d88ccc76f1901b5a1d4fec5127a61dbdc787d80f10442836bb60fafcbc70c
# Private Key: 27f67f8ef39319e0e6fbe5d7ed026a87af365ddebaa6acf0652c5829f6dc30f45f63e28858298f4c94e714740c1a643851ec4332085447f47afe8a741b78f3c6
#
# Key Pair 2:
# Public Key: c7e501ff6b66478d03271c51f986bbe16c1a4f78d655e60676807e90b52d8758
# Private Key: 
#
# Key Pair 3:
# Public Key: 3d4e862cf6168b44df52bc5f3b26215bfd49472d4221f5d79be63542688eb2ef
# Private Key: ...
#
#
# Pseudo-Identities:
# Pseudo-Identity 1: dd3a8826fd31f6503de98d583f03c36f23947a72806c26387510291d8e06b4dd
# Pseudo-Identity 2: d26e6e49454b5ead8b1a550480b2e3a80a0c23b5ed68836de00ffabee500ff92
# Pseudo-Identity 3: 5f229fea6aa2525d2ec409231e4db954953f3335560640ff40813d2033760125
#
# CS2 registration successful.
# Key Pairs:
# Key Pair 1:
# Public Key: 14f557b22c548ace4c7014009a87dbcd108cefe787473ea39efa74df6d2e3732
# Private Key: 1cbc44f6863037ed45259b5661837b8bfa8dfbab9373be819e275f0ed0210f8c2df21d1a7a0765ef0bbe4fee59a00da5c56bf3000ab7f2a2ef147a27cbe59301
#
# Key Pair 2:
# Public Key: c2548d1ed5635e7cc083ce0a037ce35310c2ce0e4cdac3270cd3facd6af2c299
# Private Key: 
#
# Key Pair 3:
# Public Key: ee06df65a3d6fea4e93c1a8770fa62d84cab509c849bcd542ae04ff2f432b06e
# Private Key: ...
#
#
# Pseudo-Identities:
# Pseudo-Identity 1: af4660ae4cb86447be2e570d69e4e8eead88a607d0c5d5cd17a30d7ef7b5cc6d
# Pseudo-Identity 2: 52ff23825e5cdbade7ee1aaa9f29d493c98f32bba66a5dd656f3e62383175de7
# Pseudo-Identity 3: 4d6b5ff3f57f5e5175a44f72c26a5fbc5ecf4c7357f4ecf9d5afa4c122dc88ff
#
# CS3 registration successful.
# Key Pairs:
# Key Pair 1:
# Public Key: b26ec5f730c470ebc5aaf3278805541e85c6227d2c6883cfe8439dcc2f15288b
# Private Key: 8c32a727e65737cf27d855c2b604c9aef70d894fcd7d3e167e98c9e98603cb0fd064f8f4486180b1ed0b17ba1cdac52a336eb02d84f44afc6245ffcb4ab81a68
#
# Key Pair 2:
# Public Key: cdb884e83ddb3f626f3e5d4c76972fca8b8f42b6dd82b6eb7691a5d67cde4c58
# Private Key: 
#
# Key Pair 3:
# Public Key: 7d229ab2e276e7946ebb28bef29dd93d3184739901564545ca06df7abe52cf9a
# Private Key: ...
#
#
# Pseudo-Identities:
# Pseudo-Identity 1: 03d24caf551300a9166c3c657c1a97344d9d26996cf6bf6250fb12af92c71cdc
# Pseudo-Identity 2: 5a5ba96d01adb1c0a3efe7da17d46cf087da9995d5b28ebe8f8147b7ca605b2c
# Pseudo-Identity 3: be6252d0bf2d07b8e2eb864d0679261a8f410313e38278af5946b78f020e8370
#
# RSU1 registration successful.
# Key Pairs:
# Key Pair 1:
# Public Key: e846de65820046040d37aa7851f06814cde9b5afe44456a3d6608bf87283f5d7
# Private Key: da53f3909773868aea71d7533bded54753534f00be8b1625fac0da2a9f634a9dd32dad655640e199851e48d32239430c15181a0fd4e5ccffa56c690d6459c1c0
#
# Key Pair 2:
# Public Key: 29cc1ed8f6e1e111ef9cd80a8e01868ceb80051ea847cf7c3bfc55d2fee881ac
# Private Key: 
#
# Key Pair 3:
# Public Key: 1a0826d0362e820dd29ceb65a7b8da89dac185d40e6de9deccd5e0cd94dac3ba
# Private Key: ...
#
#
# Pseudo-Identities:
# Pseudo-Identity 1: 64c9b248af0c742b2552b2895d378313e635a4ea8e3bdccb8e9cd28d816526cf
# Pseudo-Identity 2: 4522430ddd89cde343c3ff90af03b40dff6d2d30dc3aa644cf53bec8b8c438ee
# Pseudo-Identity 3: b88ac7d847ad458d0611c1e5bdc05372ce4a83c392b44dc4156abfaa9656581a
#
# RSU2 registration successful.
# Key Pairs:
# Key Pair 1:
# Public Key: 37676c87de6098b36380f7d4f775466fd266df387a5234d156b2caba701932d9
# Private Key: 2467daf91ce56aa686cf882d903ea17d115ef1db9b649da5cd6af8a7ab9f031cc675c49600ae03e8623f2c4711eef4a4b6e6077e5457da4fc597f26700d02fc8
#
# Key Pair 2:
# Public Key: 142d85ab228c23abdc3fcb189e0fd72d06fa26e278719b87d17a718caf3f60ef
# Private Key: 
#
# Key Pair 3:
# Public Key: 16e7ed3e9170cf2275f5874aa2a3e321a14f6c111ca3d7462dadf2bc3e9cc3ee
# Private Key: ...
#
#
# Pseudo-Identities:
# Pseudo-Identity 1: 1822184973acc4ecdb31faf5631ac59d2139ed5bbf013beaa3f222860ed35157
# Pseudo-Identity 2: 117ed22f205f6e401ed22da89f5333056fda1eb86c88feceddfb61d777d42e7c
# Pseudo-Identity 3: 1601c08b954bcdca3f2a5298e9c01ed937f4ae0dfb7d5a6db2f5042807f56eeb
#
# RSU3 registration successful.
# Key Pairs:
# Key Pair 1:
# Public Key: 37ad03fb86800279dfb744caa21b25137398f539b76dff6ca59aa3d4ee7b20fd
# Private Key: ca82e55718ad0568847766ce845f1193a0f582022af8d7fb029f3a5f4f5af28585179c4a553e701eaeddf0f2613eca9798146e82b635be983d80f6c0ce3bc1d2
#
# Key Pair 2:
# Public Key: eda91e751e6d8f21c100df522efbf19692a6d3d0d3cb64a61e7684fd4bc0d881
# Private Key: 
#
# Key Pair 3:
# Public Key: cff381ac4d374fd44a1855feb35595d8fc49c0aa20abce18ca3739be9383175d
# Private Key: ...
#
#
# Pseudo-Identities:
# Pseudo-Identity 1: 89ed4773274785f550d1a8895f652071941624ea74c90f9333715e004bebb826
# Pseudo-Identity 2: ba37da572e4d22def8ee9c427eedd10e18e7ef0c27752fd7d4c319f6b3e1872f
# Pseudo-Identity 3: b40c6bf18b42f33598d6e3e93518903977903ae4e2a507b0594a3eea7398969a

# %% [markdown]
# IN THE ABOVE CODES, WE WERE USING SHA-256 ALGORITHM, NOW WE WILL USE THE SHA 1 ALGORITHM FOR THE HASHING.

# %%
import hashlib
import os

class UDCSystem:
    def __init__(self):
        self.evs = {}
        self.css = {}
        self.rsus = {}

    def register_ev(self, ev_name, ev_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(ev_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if EV identity exists in the database or revocation list
        if ev_name in self.evs:
            return "Registration failed. EV identity already registered."

        # Step 4: Generate key pairs
        key_pairs = self._generate_key_pairs()

        # Step 5: Calculate pseudo-identities
        pseudo_identities = self._calculate_pseudo_identities(key_pairs, ev_name)

        # Step 6: Store EV information
        self.evs[ev_name] = {
            "key_pairs": key_pairs,
            "pseudo_identities": pseudo_identities
        }

        return f"{ev_name} registration successful.\nKey Pairs:\n{self._format_key_pairs(key_pairs)}\nPseudo-Identities:\n{self._format_pseudo_identities(pseudo_identities)}"

    def register_cs(self, cs_name, cs_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(cs_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if CS identity exists in the database or revocation list
        if cs_name in self.css:
            return "Registration failed. CS identity already registered."

        # Step 4: Generate key pairs
        key_pairs = self._generate_key_pairs()

        # Step 5: Calculate pseudo-identities
        pseudo_identities = self._calculate_pseudo_identities(key_pairs, cs_name)

        # Step 6: Store CS information
        self.css[cs_name] = {
            "key_pairs": key_pairs,
            "pseudo_identities": pseudo_identities
        }

        return f"{cs_name} registration successful.\nKey Pairs:\n{self._format_key_pairs(key_pairs)}\nPseudo-Identities:\n{self._format_pseudo_identities(pseudo_identities)}"

    def register_rsu(self, rsu_name, rsu_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(rsu_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if RSU identity exists in the database or revocation list
        if rsu_name in self.rsus:
            return "Registration failed. RSU identity already registered."

        # Step 4: Generate key pairs
        key_pairs = self._generate_key_pairs()

        # Step 5: Calculate pseudo-identities
        pseudo_identities = self._calculate_pseudo_identities(key_pairs, rsu_name)

        # Step 6: Store RSU information
        self.rsus[rsu_name] = {
            "key_pairs": key_pairs,
            "pseudo_identities": pseudo_identities
        }

        return f"{rsu_name} registration successful.\nKey Pairs:\n{self._format_key_pairs(key_pairs)}\nPseudo-Identities:\n{self._format_pseudo_identities(pseudo_identities)}"

    def _is_within_execution_range(self, timestamp):
        # Adjust the execution range logic according to your requirements
        return True

    def _generate_key_pairs(self):
        key_pairs = {
            512: self._generate_key_pair(512),
            1024: self._generate_key_pair(1024),
            2048: self._generate_key_pair(2048)
        }
        return key_pairs

    def _generate_key_pair(self, bit_length):
        private_key = os.urandom(bit_length // 8)
        public_key = hashlib.sha1(private_key).digest()
        return public_key, private_key

    def _calculate_pseudo_identities(self, key_pairs, identity):
        pseudo_identities = {}
        for bit_length, (public_key, private_key) in key_pairs.items():
            pseudo_identity = hashlib.sha1(private_key + identity.encode()).hexdigest()
            pseudo_identities[bit_length] = pseudo_identity
        return pseudo_identities

    def _format_key_pairs(self, key_pairs):
        formatted_key_pairs = ""
        for bit_length, (public_key, private_key) in key_pairs.items():
            formatted_key_pairs += f"Bit Length: {bit_length}\nPublic Key: {public_key.hex()}\nPrivate Key: {private_key.hex()}\n\n"
        return formatted_key_pairs

    def _format_pseudo_identities(self, pseudo_identities):
        formatted_pseudo_identities = ""
        for bit_length, pseudo_identity in pseudo_identities.items():
            formatted_pseudo_identities += f"Bit Length: {bit_length}\nPseudo-Identity: {pseudo_identity}\n\n"
        return formatted_pseudo_identities


# Example usage
udc_system = UDCSystem()

# EV registration
ev_names = ["EV1", "EV2", "EV3"]
ev_timestamp = "2023-06-28T12:00:00"

for ev_name in ev_names:
    ev_registration_result = udc_system.register_ev(ev_name, ev_timestamp)
    print(ev_registration_result)

# CS registration
cs_names = ["CS1", "CS2", "CS3"]
cs_timestamp = "2023-06-28T12:00:00"

for cs_name in cs_names:
    cs_registration_result = udc_system.register_cs(cs_name, cs_timestamp)
    print(cs_registration_result)

# RSU registration
rsu_names = ["RSU1", "RSU2", "RSU3"]
rsu_timestamp = "2023-06-28T12:00:00"

for rsu_name in rsu_names:
    rsu_registration_result = udc_system.register_rsu(rsu_name, rsu_timestamp)
    print(rsu_registration_result)
# Out:
# EV1 registration successful.
# Key Pairs:
# Bit Length: 512
# Public Key: e2335bca2aed582c05a908979c5a7e5447341db6
# Private Key: 60ea27f7a30cbd40afaa00b7732fb5fe136ad4bca57f2febc7977a79349823b19c6703718d387e8115cd1927131d1fcd3d3300961228f04ab67db6d1eacc8515
#
# Bit Length: 1024
# Public Key: cfe8c899f3945608257356df61675abe9c997265
# Private Key: 
#
# Bit Length: 2048
# Public Key: 6ea98101bfb9b3734ba93c6f8bfde6b1c25fca28
# Private Key: ...
#
#
# Pseudo-Identities:
# Bit Length: 512
# Pseudo-Identity: 125a9528fa460d5d85e26b5a32a5547596b09ae8
#
# Bit Length: 1024
# Pseudo-Identity: b032f9cef0b0b8602d21d70f3aadc40914f4f29e
#
# Bit Length: 2048
# Pseudo-Identity: 12dfd60440aa249362a6c9c87026025826254ad2
#
#
# EV2 registration successful.
# Key Pairs:
# Bit Length: 512
# Public Key: 133858e0922b99cf4d9de90285d18c15508766f0
# Private Key: 3c239649262c233c2b915656dd25979fbe13882fe9ac070a3e2e21d904935f777d56e76dd9c93f20c150f297490674402a07d7325656d25a5cc172e5dcbcdef6
#
# Bit Length: 1024
# Public Key: 9b93942f463d45424fa90c4ababf9531fffa7adc
# Private Key: 
#
# Bit Length: 2048
# Public Key: 48925c143c8abed69c47fba7212052d6ad0211f1
# Private Key: ...
#
#
# Pseudo-Identities:
# Bit Length: 512
# Pseudo-Identity: 29cce3794d32f8f56dcd5a08b846b0b3f85893bb
#
# Bit Length: 1024
# Pseudo-Identity: 65346a3c83615111ba45656a47f85b14a9c2719e
#
# Bit Length: 2048
# Pseudo-Identity: 5db8e5eb64980cbdab6ca2e6cdec710173793145
#
#
# EV3 registration successful.
# Key Pairs:
# Bit Length: 512
# Public Key: 5bccf425e4720fc8bc08040623b98d8b9436cb76
# Private Key: b5623b9baa7decae755fa68b81ba360775f2e9df479ed89d28d55fd6c29339edda543679494b4761daa811e13c6607be78456d9aef58e92dfad62fd9d1058eff
#
# Bit Length: 1024
# Public Key: dd3b2d9bb99b7648966a78c27d941b2202af2fd6
# Private Key: 
#
# Bit Length: 2048
# Public Key: 3f5288ef6357fe22645b6ba9d5c827865aaf6b8a
# Private Key: ...
#
#
# Pseudo-Identities:
# Bit Length: 512
# Pseudo-Identity: 93def6487f47738e12c8bddb35362009f12851b7
#
# Bit Length: 1024
# Pseudo-Identity: 983153755fdbbae8460d18a0cf3aa9789badeb81
#
# Bit Length: 2048
# Pseudo-Identity: ca68ba9c0f1baf7ee2f6d63c8e3e1f8443c856ea
#
#
# CS1 registration successful.
# Key Pairs:
# Bit Length: 512
# Public Key: 15f7c837d934fd7b6a0360c0291a3aa1537b174e
# Private Key: 68a478f2cb14028c829c4f209da4c68b7deb357767cc0f71395f3716fa29d732fde2017d57430819b1769b95d0a26d2767ad5f767241c1ec3843bac7d2649d99
#
# Bit Length: 1024
# Public Key: dff73ecb490c9b41252733b9aa41efa1dff8c0f4
# Private Key: 
#
# Bit Length: 2048
# Public Key: 77224d8a5734d4715a4dc4cd207444b2c7c659f9
# Private Key: ...
#
#
# Pseudo-Identities:
# Bit Length: 512
# Pseudo-Identity: 1d15920a4d483989763493211e1784468cce013c
#
# Bit Length: 1024
# Pseudo-Identity: c4c5c3c2d2620e114f5103ba3ff08b371b6097ba
#
# Bit Length: 2048
# Pseudo-Identity: 645f25cabfc5197c5845103ba9ffd905c2bc7731
#
#
# CS2 registration successful.
# Key Pairs:
# Bit Length: 512
# Public Key: 40ccc54302bb4fdebb8135cf2dc19ef020cded14
# Private Key: e6a1ad8aa8cb3ff957cda7efb96350b520327367839830ee4d603c424ec771619b9ff5876b79ea5f057dc534d0e47718347c86855ded73de50c1cca0f0e4d311
#
# Bit Length: 1024
# Public Key: 407409e4554ff64106f49487888922b793f133e8
# Private Key: 
#
# Bit Length: 2048
# Public Key: 76b731c80e7d5f424abb8859a608489040b57e12
# Private Key: ...
#
#
# Pseudo-Identities:
# Bit Length: 512
# Pseudo-Identity: c7875370530379a1756d2a0bdda44754209f4279
#
# Bit Length: 1024
# Pseudo-Identity: 3332d5eb9258c2cf04a4e2676f81d4250fb7101e
#
# Bit Length: 2048
# Pseudo-Identity: 7ebbdb4cea2d28cbabf93eb65ee461c52deaa41a
#
#
# CS3 registration successful.
# Key Pairs:
# Bit Length: 512
# Public Key: 807b7050be1725626f54e5b6a3479521492580a8
# Private Key: 54432ad564f37b5c9b047b4a3ef0330d52f9835eedf229025704f8ca7d5795b35023223f07daca346270eef546b5d24df9266bded3b1b3cf16aa98920f3b665a
#
# Bit Length: 1024
# Public Key: 8c0ba0db8e3f68ba86ee3b9b8c073400632acfc1
# Private Key: 
#
# Bit Length: 2048
# Public Key: e5d70bed2df32bae4116decd0e4c3166227f11be
# Private Key: ...
#
#
# Pseudo-Identities:
# Bit Length: 512
# Pseudo-Identity: c03b864ef74ee0ebe5baf905d14a3d02aa90e473
#
# Bit Length: 1024
# Pseudo-Identity: 43ccd0db6f7253477688fd9f3ab40c41b7d08da0
#
# Bit Length: 2048
# Pseudo-Identity: 3be8a866ccb9c155abf5754e5d7331287189e59c
#
#
# RSU1 registration successful.
# Key Pairs:
# Bit Length: 512
# Public Key: 950511b20f6d4fb56c7de0b75904d7068a3f3a32
# Private Key: c0e4b88c9cc3b878f215c8fda6dc440d0b591a4076d23204c1cdfb239cf9b5eba572795499c829a16095bafea57e96448b48e000c0dd46770520ab3ac6963b81
#
# Bit Length: 1024
# Public Key: 1e1e10b7b0357327f53f05575fff69a032ec02c8
# Private Key: 
#
# Bit Length: 2048
# Public Key: 7ef5bcf6e4c54672d5c8df0119ceed00e236fa8a
# Private Key: ...
#
#
# Pseudo-Identities:
# Bit Length: 512
# Pseudo-Identity: 4d4baa7eb6c38ff5a3afab75bb4b36deaeb3b016
#
# Bit Length: 1024
# Pseudo-Identity: cf347a0c341737092e2820f8050c6d949d3090d7
#
# Bit Length: 2048
# Pseudo-Identity: 74383f7968c59922f24072916ea0ca385eda29d7
#
#
# RSU2 registration successful.
# Key Pairs:
# Bit Length: 512
# Public Key: 981d4dc7292223300fb52f7bcb6bb2ddd3083494
# Private Key: b3b98e164993e5945686ed0686f4b91f7759179a7ba505b66e4e2004a550c525ac14168e98eb84be30053be4187d826a928fd58fb49243d37fde01f11bcfbc6e
#
# Bit Length: 1024
# Public Key: dfbf47d18c4f7c91216d366fca836c1a06f629b2
# Private Key: 
#
# Bit Length: 2048
# Public Key: 668cd02e9a38851784b956c0b7b01c49eacdd22e
# Private Key: ...
#
#
# Pseudo-Identities:
# Bit Length: 512
# Pseudo-Identity: 5e6f1cd9077c26ca5a327f830d5fd963ef7bfb98
#
# Bit Length: 1024
# Pseudo-Identity: 7e8541d1eeacd596a6cdb454cf6ad5c01752c8d6
#
# Bit Length: 2048
# Pseudo-Identity: 7aad8faffa058a11324eddc8ea9557234f83d3de
#
#
# RSU3 registration successful.
# Key Pairs:
# Bit Length: 512
# Public Key: 05bc44e238764789397a60fc9fa7d1431c21bbff
# Private Key: 7b165cf9073c7a940474edf51c6fbe4ae07a8b8c2e4045ad3473dad0e161b0590260d52180a4fb83549f91b4eaef2e755fd2d0c257f71f2cb26c8594c7fa36c3
#
# Bit Length: 1024
# Public Key: 8213a7ac89f6be30d34f6f91d5d0231ec97bdbd1
# Private Key: 
#
# Bit Length: 2048
# Public Key: 2858b46218a4691da15ea2b6b77a8948b07acec2
# Private Key: ...
#
#
# Pseudo-Identities:
# Bit Length: 512
# Pseudo-Identity: 91cc4c43923deab994821c1f26bf64dc20c599ba
#
# Bit Length: 1024
# Pseudo-Identity: 280054c0f9c40b9df716c3784f9423a091afdc7e
#
# Bit Length: 2048
# Pseudo-Identity: 28288637f51ad772cea5fa7951d0e39dc3396f94
