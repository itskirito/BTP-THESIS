# %% [markdown]
# **WORKING IOF THE REGISTRATION FUNCTION:** The given code represents a basic utility data center (UDC) system. It allows for the registration of Electric Vehicles (EVs), Charging Stations (CSs), and Roadside Units (RSUs). Each entity is assigned key pairs and pseudo-identities to enable secure communication within the system.
#
# The core component of the UDC system is the UDCSystem class. It includes the following attributes:
#
# evs: A dictionary used to store registered EVs. Each EV is associated with a dictionary containing its key pairs and pseudo-identities.
# css: Similar to evs, this dictionary stores registered CSs (Charging Stations).
# rsus: Similar to evs and css, this dictionary stores registered RSUs (Roadside Units).
# revocation_list: A set that keeps track of revoked identities.
# The UDCSystem class provides three registration methods: register_ev, register_cs, and register_rsu. These methods share a similar registration process, which can be summarized as follows:
#
# Step 2: Verify the timestamp: This step ensures that the registration occurs within the allowed execution range. The execution range can be customized based on specific requirements.
#
# Step 3: Check if the entity identity exists: This step verifies whether the entity (EV, CS, or RSU) is already registered in the system or is present in the revocation list. If the identity is found, the registration process fails.
#
# Step 4: Generate key pairs: Random key pairs are generated for the entity using different bit lengths (512, 1024, and 2048). Each key pair consists of a public key and a private key.
#
# Step 5: Calculate pseudo-identities: Pseudo-identities are derived for each key pair using a secure hash function (SHA-256). The pseudo-identity is computed by hashing the concatenation of the private key and the entity identity.
#
# Step 6: Store entity information: The generated key pairs and pseudo-identities are stored in the respective dictionaries (evs, css, or rsus) using the entity's name as the key.
#
# The UDCSystem class also includes several helper methods:
#
# _is_within_execution_range: This method checks if the provided timestamp falls within the allowed execution range. The specific logic for the execution range can be customized.
# _generate_key_pairs: It generates random key pairs with different bit lengths.
# _generate_private_key: It generates a random private key with the specified bit length.
# _derive_public_key: It derives the public key from the private key using the SHA-256 hash function.
# _calculate_pseudo_identities: It calculates the pseudo-identities for the given key pairs and entity identity using the SHA-256 hash function.
# _format_key_pairs: It formats the key pairs for display purposes.
# _format_pseudo_identities: It formats the pseudo-identities for display purposes.
# The provided example usage demonstrates the registration process for EVs, CSs, and RSUs by creating instances of the UDCSystem class and calling the respective registration methods for each entity. The registration results are then printed to the console, displaying the generated key pairs and pseudo-identities for each entity.
#
# Overall, this code establishes a simple UDC system that allows the registration of EVs, CSs, and RSUs. It provides secure communication capabilities through key pairs and pseudo-identities.

# %%
import hashlib

class UDCSystem:
    def __init__(self):
        self.evs = {}
        self.css = {}
        self.rsus = {}
        self.revocation_list = set()

    def register_ev(self, ev_name, ev_timestamp):
        # Step 2: Verify timestamp
        if not self._is_within_execution_range(ev_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if EV identity exists in the database or revocation list
        if ev_name in self.evs:
            return "Registration failed. EV identity already registered."
        if ev_name in self.revocation_list:
            return "Registration failed. EV identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, ev_name)

        # Step 6: Store EV information
        self.evs[ev_name] = {
            "public_key": public_key,
            "private_key": private_key,
            "pseudo_identity": pseudo_identity
        }

        return f"{ev_name} registration successful.\nPublic Key: {public_key}\nPrivate Key: {private_key}\nPseudo-Identity: {pseudo_identity}"

    def register_cs(self, cs_name, cs_timestamp):
        # Step 2: Verify timestamp
        if not self._is_within_execution_range(cs_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if CS identity exists in the database or revocation list
        if cs_name in self.css:
            return "Registration failed. CS identity already registered."
        if cs_name in self.revocation_list:
            return "Registration failed. CS identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, cs_name)

        # Step 6: Store CS information
        self.css[cs_name] = {
            "public_key": public_key,
            "private_key": private_key,
            "pseudo_identity": pseudo_identity
        }

        return f"{cs_name} registration successful.\nPublic Key: {public_key}\nPrivate Key: {private_key}\nPseudo-Identity: {pseudo_identity}"

    def register_rsu(self, rsu_name, rsu_timestamp):
        # Step 2: Verify timestamp
        if not self._is_within_execution_range(rsu_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if RSU identity exists in the database or revocation list
        if rsu_name in self.rsus:
            return "Registration failed. RSU identity already registered."
        if rsu_name in self.revocation_list:
            return "Registration failed. RSU identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, rsu_name)

        # Step 6: Store RSU information
        self.rsus[rsu_name] = {
            "public_key": public_key,
            "private_key": private_key,
            "pseudo_identity": pseudo_identity
        }

        return f"{rsu_name} registration successful.\nPublic Key: {public_key}\nPrivate Key: {private_key}\nPseudo-Identity: {pseudo_identity}"

    def _is_within_execution_range(self, timestamp):
        # Adjust the execution range logic according to your requirements
        return True

    def _generate_key_pair(self):
        # Replace this with your key pair generation logic
        public_key = "PUK"
        private_key = "PRK"
        return public_key, private_key

    def _calculate_pseudo_identity(self, private_key, identity):
        # Use a secure hash function, such as SHA-256, to calculate the pseudo-identity
        hash_input = private_key.encode() + identity.encode()
        pseudo_identity = hashlib.sha256(hash_input).hexdigest()
        return pseudo_identity

# Example usage
udc_system = UDCSystem()

# EV registration
ev_names = ["EV1", "EV2", "EV3"]
ev_timestamp = "2023-06-28T12:00:00"

for ev_name in ev_names:
    ev_registration_result = udc_system.register_ev(ev_name, ev_timestamp)
    print(ev_registration_result)

# CS registration
cs_names = ["CS1", "CS2", "CS3"]
cs_timestamp = "2023-06-28T12:00:00"

for cs_name in cs_names:
    cs_registration_result = udc_system.register_cs(cs_name, cs_timestamp)
    print(cs_registration_result)

# RSU registration
rsu_names = ["RSU1", "RSU2", "RSU3"]
rsu_timestamp = "2023-06-28T12:00:00"

for rsu_name in rsu_names:
    rsu_registration_result = udc_system.register_rsu(rsu_name, rsu_timestamp)
    print(rsu_registration_result)
# Out:
# EV1 registration successful.
# Public Key: PUK
# Private Key: PRK
# Pseudo-Identity: 6ae6fb7227417494c41ca9004b724cea019fe9c5bc3ca0511f8e9dabdde5a2e2
# EV2 registration successful.
# Public Key: PUK
# Private Key: PRK
# Pseudo-Identity: 3207af61db99ad5ea5b52f37c3245e8679c398a92a29ce6b845fd1352d8291c8
# EV3 registration successful.
# Public Key: PUK
# Private Key: PRK
# Pseudo-Identity: e5c28bf6eaada40017e7038c75a2bd7446b3cbb1534a9a76d4e7ebc8941e9cdb
# CS1 registration successful.
# Public Key: PUK
# Private Key: PRK
# Pseudo-Identity: cca7eeca32d5fa41ac5663e39b46013ad45e8f9f187d418754e06e002042de66
# CS2 registration successful.
# Public Key: PUK
# Private Key: PRK
# Pseudo-Identity: 757a4149d8e6bd00d1c4f471e1c2be8a81f20e4fea6b10f64395838d63d3dd41
# CS3 registration successful.
# Public Key: PUK
# Private Key: PRK
# Pseudo-Identity: 378f034582fa4ac3ffbe02459b85a4cff7a005633d4ec005bd61f226c51ab123
# RSU1 registration successful.
# Public Key: PUK
# Private Key: PRK
# Pseudo-Identity: 714edd2340b2efc1f4f5d8a089bfa28406c964e64b9b701031ea18a6226d32f5
# RSU2 registration successful.
# Public Key: PUK
# Private Key: PRK
# Pseudo-Identity: c105667673c7dd3e714726ad1390bb51ba5286187b22f378b9c00139f36c1dd8
# RSU3 registration successful.
# Public Key: PUK
# Private Key: PRK
# Pseudo-Identity: c282c7991d2ac148c28f1175177d190b9fa4e3c8dbe6cafe7590a644bf65d929

# %% [markdown]
# IN THIS THE KEYS SIZE IS TAKE 2048 BITS. High-strength key

# %%
import hashlib
from cryptography.hazmat.primitives.asymmetric import rsa
from cryptography.hazmat.primitives import serialization

class UDCSystem:
    def __init__(self):
        self.evs = {}
        self.css = {}
        self.rsus = {}
        self.revocation_list = set()

    def register_ev(self, ev_name, ev_timestamp):
        # Step 2: Verify timestamp
        if not self._is_within_execution_range(ev_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if EV identity exists in the database or revocation list
        if ev_name in self.evs:
            return "Registration failed. EV identity already registered."
        if ev_name in self.revocation_list:
            return "Registration failed. EV identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, ev_name)

        # Step 6: Store EV information
        self.evs[ev_name] = {
            "public_key": public_key,
            "private_key": private_key,
            "pseudo_identity": pseudo_identity
        }

        public_key_pem = public_key.public_bytes(encoding=serialization.Encoding.PEM, format=serialization.PublicFormat.SubjectPublicKeyInfo).decode()
        private_key_pem = private_key.private_bytes(encoding=serialization.Encoding.PEM, format=serialization.PrivateFormat.PKCS8, encryption_algorithm=serialization.NoEncryption()).decode()

        return f"{ev_name} registration successful.\nPublic Key:\n{public_key_pem}\nPrivate Key:\n{private_key_pem}\nPseudo-Identity: {pseudo_identity}"

    def register_cs(self, cs_name, cs_timestamp):
        # Step 2: Verify timestamp
        if not self._is_within_execution_range(cs_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if CS identity exists in the database or revocation list
        if cs_name in self.css:
            return "Registration failed. CS identity already registered."
        if cs_name in self.revocation_list:
            return "Registration failed. CS identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, cs_name)

        # Step 6: Store CS information
        self.css[cs_name] = {
            "public_key": public_key,
            "private_key": private_key,
            "pseudo_identity": pseudo_identity
        }

        public_key_pem = public_key.public_bytes(encoding=serialization.Encoding.PEM, format=serialization.PublicFormat.SubjectPublicKeyInfo).decode()
        private_key_pem = private_key.private_bytes(encoding=serialization.Encoding.PEM, format=serialization.PrivateFormat.PKCS8, encryption_algorithm=serialization.NoEncryption()).decode()

        return f"{cs_name} registration successful.\nPublic Key:\n{public_key_pem}\nPrivate Key:\n{private_key_pem}\nPseudo-Identity: {pseudo_identity}"

    def register_rsu(self, rsu_name, rsu_timestamp):
        # Step 2: Verify timestamp
        if not self._is_within_execution_range(rsu_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if RSU identity exists in the database or revocation list
        if rsu_name in self.rsus:
            return "Registration failed. RSU identity already registered."
        if rsu_name in self.revocation_list:
            return "Registration failed. RSU identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, rsu_name)

        # Step 6: Store RSU information
        self.rsus[rsu_name] = {
            "public_key": public_key,
            "private_key": private_key,
            "pseudo_identity": pseudo_identity
        }

        public_key_pem = public_key.public_bytes(encoding=serialization.Encoding.PEM, format=serialization.PublicFormat.SubjectPublicKeyInfo).decode()
        private_key_pem = private_key.private_bytes(encoding=serialization.Encoding.PEM, format=serialization.PrivateFormat.PKCS8, encryption_algorithm=serialization.NoEncryption()).decode()

        return f"{rsu_name} registration successful.\nPublic Key:\n{public_key_pem}\nPrivate Key:\n{private_key_pem}\nPseudo-Identity: {pseudo_identity}"

    def _is_within_execution_range(self, timestamp):
        # Adjust the execution range logic according to your requirements
        return True

    def _generate_key_pair(self):
        # Generate a 2048-bit RSA key pair
        private_key = rsa.generate_private_key(
            public_exponent=65537,
            key_size=2048
        )
        public_key = private_key.public_key()
        return public_key, private_key

    def _calculate_pseudo_identity(self, private_key, identity):
        # Use a secure hash function, such as SHA-256, to calculate the pseudo-identity
        hash_input = private_key.private_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PrivateFormat.PKCS8,
            encryption_algorithm=serialization.NoEncryption()
        ) + identity.encode()
        pseudo_identity = hashlib.sha256(hash_input).hexdigest()
        return pseudo_identity

# Example usage
udc_system = UDCSystem()

# EV registration
ev_names = ["EV1", "EV2", "EV3"]
ev_timestamp = "2023-06-28T12:00:00"

for ev_name in ev_names:
    ev_registration_result = udc_system.register_ev(ev_name, ev_timestamp)
    print(ev_registration_result)

# CS registration
cs_names = ["CS1", "CS2", "CS3"]
cs_timestamp = "2023-06-28T12:00:00"

for cs_name in cs_names:
    cs_registration_result = udc_system.register_cs(cs_name, cs_timestamp)
    print(cs_registration_result)

# RSU registration
rsu_names = ["RSU1", "RSU2", "RSU3"]
rsu_timestamp = "2023-06-28T12:00:00"

for rsu_name in rsu_names:
    rsu_registration_result = udc_system.register_rsu(rsu_name, rsu_timestamp)
    print(rsu_registration_result)
# Out:
# EV1 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEA0swucA91TNC5cFRypsTB
# 6tpdbonqqGCJugiXByqKm1GthKPfqbeQcNIPxZRNgu0hmUy0nw5HcfIu06UrxhQl
# Ggp6R56oU3/+mHc4xYOBa3K1vtw0uYlaAuoEnoi1Mh6njIGttH2ctwRRji5+R7EO
# X2UebsdHaYIEPYm4TMSuSrietBFT7CDtwA3+B/4v2nCdRwBVwxQdB9pV998gXRTf
# 9mwsFUL2rGmbGzuT17uFyajU0Q3ZSc+VAb66LL6cOMEF0a4YGfc3K+ZA/fTQEFBY
# h1XLSpb34fo6aAomsUzap/RRVe5j3cQXq45Ame61F3onfwA9A6dl8TMgdVrDB83B
# rQIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIEvgIBADANBgkqhkiG9w0BAQEFAASCBKgwggSkAgEAAoIBAQDSzC5wD3VM0Llw
# VHKmxMHq2l1uieqoYIm6CJcHKoqbUa2Eo9+pt5Bw0g/FlE2C7SGZTLSfDkdx8i7T
# pSvGFCUaCnpHnqhTf/6YdzjFg4FrcrW+3DS5iVoC6gSeiLUyHqeMga20fZy3BFGO
# Ln5HsQ5fZR5ux0dpggQ9ibhMxK5KuJ60EVPsIO3ADf4H/i/acJ1HAFXDFB0H2lX3
# 3yBdFN/2bCwVQvasaZsbO5PXu4XJqNTRDdlJz5UBvrosvpw4wQXRrhgZ9zcr5kD9
# 9NAQUFiHVctKlvfh+jpoCiaxTNqn9FFV7mPdxBerjkCZ7rUXeid/AD0Dp2XxMyB1
# WsMHzcGtAgMBAAECggEABMlyt4Q+WW12/JRKWzumHK9zRjaXD9ZLYmBeD6FZbvAC
# pPu0sU20F7/JcGbvAK1iYTES+/auzClgA1nhndioxAffYX96mpTSQwOYFDIpjvdW
# pbwp7VmvY9gNHU2E8dus2d27BFmC5MwSDwzCvN2KMkPhVkortrtnXb9iIkooHBW9
# JMuxuTrVhPhBKs7Wl11rCIJSKSwnJWdYzrtQj+0dbhFMHAJeHAGwdnX/nrEZPbA6
# Fho4bvearifE7puVTizMrQzbm9n+RNNTUMixfubgJDZqHuJlwr6eyQXLJqQrvBPP
# afFg7PZyeK2Gv1ZHlPQzApZKqOo1VpHa0aSsN3WsOQKBgQDvFwsaRFBHLwmoWXKn
# qztV63XNKNqTDU30DpSSAdHxZYxKfYaItkpxzHvi9eLzQ4WcMbYueQoaNLS9tYfS
# IaPMU5g/N+5QHO5LsmDNLwOzH03uLVK8RbOZtAB+Ekf4QeQ4/i48w4rZbfzWYxS7
# +Lx3Fk2UcSQTGUBCP1pKrUXatQKBgQDhtOBK9L0KiljmKbTKKO2Q/f2U8hHrwk0L
# gPGTAJ9fCCCSMs+LstAVSP40RKxrV2X1WezMHGh7DqvLHmi7QK43ETHQrR91bmuS
# BjZCKjZn5WtcDWUmCo6yT2Va988buQJK3xNNGhLPLxODcBWiCnAd7sYjve0cnHwR
# g7XtFd+OGQKBgQCcEKObqrnoLUkVjgWscrZRmFgV6jP6xzV6OMY8JFoBQ7L2sMdP
# mAYyEDNR7AUPm6SsVzq/TR0ODBdqugMFZBYCexKnOYAi5S+bU72iUa0NkEKTVRxr
# bugUTY4AvTgjUgeCOFDAMzgAQ65F1vki1fNXnMRZQB03JkVuuOHcWwx8/QKBgGmU
# 1AscO0Yv+3AHeHPM+3yE49eF+U4gwSutcNQESYkJ4zqgnCfMSLx8PbWznjhEVQSV
# wUilzVYrQb+thO57TkOiPnxQT9P+CEHxt/XxiyvEzRjthzBpZeERdOc93tsoC2N8
# wKmjlcLnUah9iREY8uN9q6BSmxV0OjFzPGogfkgZAoGBANyanfU9IZgQgXa9SeUY
# y5iuhZP2yE/FuAfEoFSkNIA/RJv/iujcJDCLFcJYGL5Wzlg3jQm212w2SwWvTCY3
# gZvnZeUTj33OuXoPIFDcLpQPDNYX+nmYA/L2HBRVFqzdw2fu7jVEBuxjd0eVmM8q
# SLp5i562WRjaHlFpufMVLHSI
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 0421b9d52939e6fb2ac876b511c0b9352e112a7f1c8226c55ff38abc93e40946
# EV2 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAj9nHJmjnsFqDMOJvuqRm
# nrvE5xgDZICsEqf1JppNN1esQ8xucwq4J85+BeQaWkPKjrpAI6PeSUeyYYQJ69D0
# gMdI32mcblwmoEvm2e86a8u8iBH9FTndPAfkoRTtI5ETqR8GIA2WR3GYrsS9SS0/
# ON6AB9JeN9c1Ik3E7PtOWdU701HOuKahpi7cEvVZJ1//Vey44/4RF6loQXsRHTsU
# q5MvvFKGqRSiYA1DsZoHWzPTAbErY6M5KyHLbldFrLS3ujAHJlI5XrZc6r3JjphC
# hyB+hPEMI354Vf5G8NQAoiy8e9sY+1hHn9Syn/d/YXGTJ/XmJ3TnAwkehOPUlipY
# 0wIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIEvgIBADANBgkqhkiG9w0BAQEFAASCBKgwggSkAgEAAoIBAQCP2ccmaOewWoMw
# 4m+6pGaeu8TnGANkgKwSp/Ummk03V6xDzG5zCrgnzn4F5BpaQ8qOukAjo95JR7Jh
# hAnr0PSAx0jfaZxuXCagS+bZ7zpry7yIEf0VOd08B+ShFO0jkROpHwYgDZZHcZiu
# xL1JLT843oAH0l431zUiTcTs+05Z1TvTUc64pqGmLtwS9VknX/9V7Ljj/hEXqWhB
# exEdOxSrky+8UoapFKJgDUOxmgdbM9MBsStjozkrIctuV0WstLe6MAcmUjletlzq
# vcmOmEKHIH6E8QwjfnhV/kbw1ACiLLx72xj7WEef1LKf939hcZMn9eYndOcDCR6E
# 49SWKljTAgMBAAECggEAEzxIVJsHjD32OAW3cgpEzKoIIOzFm11XZSE/d1t/wsw+
# 9UvzYv/Gc1A56ti/K13QSrieFgX2Fe9363FIEFf/Me80D+fj6p/47EtqAa9rLPnv
# 6nQZVwrHSh02FdIiCbT/H4jN/WBDvabzhz84nn3l69lY3nLjdW0aJk2m7ReHuRxG
# kU1WMLrNNsD+Mk0NnKqRYPZBoODNIwoaV3Vf3hPrhXEetoPdfpnap8WFenl1hAPY
# ehOpPA/Q3Vc7aIvP2HezeUbs/2C1hfL8mVTcXIytp4fcGdqU2lxBwEkkQPmR0lP8
# 8aRap7XTcZcZSlklpiWxFpv9gNvXHVXnDH8xcZCWnQKBgQDCyDfRdrCJw4PijUFY
# TEcmiNHoXvEdiTjMCOOQ+BLENUEadMZjJzEEZ9pvbLncay8M5seKi/QiWGc+QvO7
# pAw+k6mQx3EEHfbTAe4VLqHbn5hOFhTHSMHQYX09KNiz1hjNzTd42j0PBKlKketp
# AIlyEwLRAm9SmeILw49RbP55bwKBgQC9D7hGbpU+COaCplcgSBi+SlU8bNm2hb4G
# lJbCwARSd53PlxMzT+WniGYWzLav1rIiFOQRo2/J6vUSD8qleGwQe/k2yBw0ZrHD
# iRli62t2oQc6iMBowf25A4HxUArCVb7M6MMx8IM56JSPDfYeuX88hI1N7/Kx5SwH
# MK3yZJK83QKBgAbv1n0ROwxM+D9zRGZ+oPIQYVljODcTEgDCOEiLbS+rrdvhWMdj
# N+2uPStGtf/RmWVeOrEGdvVaLKMdA00ldIIuBBXx5GZ/IrE1GmOKu5z0vBnb03Wd
# c7mWHz20XLNa5ps9ucIGE7KbOeQ7+iRNLpfvcWQ8L/bDIDfHCS2fMhjlAoGBAKNA
# RbCboEcWzGSYWbdISgVWjk9E9qGCztlDyQKVZ6YGH8C3BR9TqEyHnQ+m6UDgtKR1
# QZJxe//w4HkeJa/IUhfR1RoWpTQiUPE1GzStb/fZiDJlDy/mAr6VZskGgqPYAo9R
# leszcTy5tj3oolNZfaK2GoXn4br21pPG1wztB0AJAoGBAKcbah1S7NiVni7q9zYX
# H00r9mLZoLWZX24mmmK3zU93u+Gcat7lmmQl5Ex4tmrmCN/OG4bgSJNqCaMQvrf0
# 8cvWDngdT9N80BqvI2+bb/0hGfBixQq1EypgTb4bK7TYLi05x2NAyug0qn/JOlV4
# 5pPUI/W8muSH08MqW8Mko8ZQ
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 3cbaf7ec43d922dda90ff76abd980d106692216c728377dc4900c29b70458cfd
# EV3 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEA1LONaa53ly9mJfbrWmIF
# FPydYk7Nmrjw5lG1y4c36fNaUPDTl3YtGpaHdHnepNdelCPimAvVQ4+KE7HZX4EW
# HHNP/oQIaVPNAWIV9tV8io/2JGBFGGsRalbpn52WoOcU/kJp/HImeXlb8OIlt2f7
# SvRt40tMQNwZzEtt4yTT5mrpSG+BSWM5ksP0wAMIQOaj2bSXcUIK0owLYW9rshJk
# QjfE7iBEI4uRmlbK677N+7luLcQMzVxFgagwznZ+kW1BAIfsi3iVCgXJeT5WumEi
# XTjQ5ZtibyJAJFD6lreuf5Iz7vFyzGQu6BuxQzBzllzBWP4q93aTCIGzVT2K9Xhe
# ZQIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIEvQIBADANBgkqhkiG9w0BAQEFAASCBKcwggSjAgEAAoIBAQDUs41prneXL2Yl
# 9utaYgUU/J1iTs2auPDmUbXLhzfp81pQ8NOXdi0alod0ed6k116UI+KYC9VDj4oT
# sdlfgRYcc0/+hAhpU80BYhX21XyKj/YkYEUYaxFqVumfnZag5xT+Qmn8ciZ5eVvw
# 4iW3Z/tK9G3jS0xA3BnMS23jJNPmaulIb4FJYzmSw/TAAwhA5qPZtJdxQgrSjAth
# b2uyEmRCN8TuIEQji5GaVsrrvs37uW4txAzNXEWBqDDOdn6RbUEAh+yLeJUKBcl5
# Pla6YSJdONDlm2JvIkAkUPqWt65/kjPu8XLMZC7oG7FDMHOWXMFY/ir3dpMIgbNV
# PYr1eF5lAgMBAAECggEAHD3d9i0H7H9K5xoOvGC874EuLX4snxFUzSQGySgiVLIu
# 6QXc9mSmzvuzLxQ6a3U8NdvA67LQhYiyyvQnml5zruHhunfR/Rg3JWqeY3iLsYM1
# abWNnxUiShYRrZOZSzJ7j1oGpBINCT6DpmuEmgJYs6ZaS9502LzQwRc31zvN1e9Y
# aZd/Q6I7J+FQl+LBdjjOC65HbDF5Za0QEgn/0keY29lkbk7Spb4SI5lp3lDMBvAR
# OSjXL/vL7ij92sKbFvUvCrp8bw4sdrvPTcGz0xIf/wLhdcXOGk2NVaPdzSI5A/Sp
# LpP6prwA0olV+i0VKhbIr76Cv6O7jFfpXheyJ+kdaQKBgQD+Rgdpfk/RcgIm4QDb
# ni3pXrG4qAdkZI4LBiOkC+xZx+PNG4FcxhOxEs/htC0iJupqvVFljrdFwY/Gcb1y
# zvMx/uqZd8jBdWJtzTo77VVl+rqrWuNEZ06Q2EVp0hzoD0HXzkVVAbnUOii5EjSO
# DTVtsVIegvCYLN8JL9VM35yoaQKBgQDWJUONDDP8z2fvp0NjCkFWNl3EBcjYkg+/
# rNZMOB19k0pRT4F+OciT8DyAxYUdIC+GuzF4yhIcU0Db/LL9bjn0La00yddOhQBD
# a8saLrZYHLaxB4BCzTYrXhpOa4Hf5z5unFT4LhkuwzbzLMwcC3fecKUKKdQAfVFu
# eeXTlYmmnQKBgFd6mkQ1+5nwIkNj95qXEe6O8I+550knuyKZyxs+KuM8fOfsxZW4
# Y7/w2+onxbtRLibo2R8aeX0bOa6pJOdhwZN6wxVne37rNqDWEWnanh3GpAAd9cBr
# 1kDI1yCv89f2n81yHrI/NMKJ+8aoN8KDUtVZQwpSPBnunhEYDscyyz+5AoGACqv8
# u9C53oVvho/tWcgvDV7UOWqYYcKVqlWwsEezoIhwkbDGoUW76zNzsG8nfRYXiD1X
# 788SK/syJkRnnx2ZIcQM965/XlhedP2wN3PQfn+f0x6uk6WqZ2rfIL1W0ZOylsyP
# p3aUprHv0RqQaW1g4eL3NpRzDjswjbLhczPmkjkCgYEA3uoVSlhzNotFqFSRdGQx
# 80EoS8Tdb2Z68ZBYS+GrMg8C1qYYmZkMv64mlgnfVS68HrpfLwkXIMZv7yY4++5G
# lCzMDW29srf5cxDHVQ+YM2unLozrAk0KKczY3Dy/e6xAc+tT1TnsSKiaipX47Gi7
# npW4ULk78LrN4wJlOdvh23k=
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 112565222b5c023cddbcd446d4d36846288f2223a5ae6743909c22d6193846c3
# CS1 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAwRmL0W5nH5cIY8GdI2rm
# qEMsJiZo4bYJRrAGnF8o8BSS35TnmYhWyTecscVOhzZYP+LFo49tF1GZuZ0sd3wS
# 0AKsBDAjasozxEe4qT12aB3+a5jpRI++ZDrxSlXl68kFaidPHSkLNIsNx4oOASAz
# 0lGUfc9F9o+CQeGnwrGg447GPvQLdzdUtR/bGQHhUnrEl8z89Rw6bx0iYfgurfuN
# F2VEyPVymMVwCwgTPHV/K/xsAKZXia/rHZ92tNVLZ3FIpb014CAuHlOcxAuODDMi
# Xt64VtsXwo4HC3V6hYU5m7XKKY5/W4Szwizw+wa91SYyBatT/WSTyy87uaAx9umj
# 7QIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIEvQIBADANBgkqhkiG9w0BAQEFAASCBKcwggSjAgEAAoIBAQDBGYvRbmcflwhj
# wZ0jauaoQywmJmjhtglGsAacXyjwFJLflOeZiFbJN5yxxU6HNlg/4sWjj20XUZm5
# nSx3fBLQAqwEMCNqyjPER7ipPXZoHf5rmOlEj75kOvFKVeXryQVqJ08dKQs0iw3H
# ig4BIDPSUZR9z0X2j4JB4afCsaDjjsY+9At3N1S1H9sZAeFSesSXzPz1HDpvHSJh
# +C6t+40XZUTI9XKYxXALCBM8dX8r/GwApleJr+sdn3a01UtncUilvTXgIC4eU5zE
# C44MMyJe3rhW2xfCjgcLdXqFhTmbtcopjn9bhLPCLPD7Br3VJjIFq1P9ZJPLLzu5
# oDH26aPtAgMBAAECggEAA9Pw+3NaqaZ8UkHtzrHD+x+Yb0nWosF8OJcCYoouYmf+
# ALRPzQbbYDzGfJhX4K1OnYxDdQ/BpAiIPsTjXfEAjHgTweIpvuhdk1gFTJw9Iyjp
# DhKnbnus/16obDFSD/+u/aDkMW9KsL11m02HeTU9Yb91Qp3fxK3+m+C7IHcV+ed7
# S3q3seLnMZoCCZ50hn8VAGHqSE5bjayu9CPTvl4/nTl+HjC/DXzn606IVlxQO0qF
# JY/5pTZW+JLKnbEV6HlSZsOFim0AG8f7d4CxVNO7XZ3vTATlOLXYKUerW5sYlyNA
# QviFSKVI7tcJVh2m8RV1Q1bkpNgZcNNlh9Yjr8xbTwKBgQD2msMj6emRytULaZxH
# OmZcZHFqiUsADMTGM8HCG2XcfCCCZOcLlAw8DeECYDMnwlUyxVpL7fFiOKEic+6S
# 79Do3IlO9Hs1zV/el5c8vytrF2qDNxaakCb/YS9zW134H2RWlwfYS/vqhXLX5aWf
# 59s1Ey4+v6+jq0YtbqyLL9x7EwKBgQDIdO34zmBd5MSX3MCkpU9kEc9fJQyI5umo
# ozzJFObP4IKp9Bfg6bxfylswmzxpbBEVjKeIqjr32bW+qdskAv5bwyzQXmJ97Qe6
# M+kq8CRIb49aA6ZsqCBhVLjIOAWFjY7zYYDru4MWyM1fwuqc+i/Cfw11MK+5yV8/
# glrVyT5E/wKBgDVqyKJa5NFD0moqckOrjsisqTSekLRuD6GvTGUzchkUeiZEnReQ
# 9iV8DCVrmSkfmzzoKusPm53fDmhcHG2PrP0D6GpF4vqAhie9RnFOJ6WG6PeLU0Yf
# u5LOBm1CeVRp2F45UOW1b9gZGAtUH1BH9N/GS9ojw3P8gbMNqipsL6IpAoGABoVn
# SHTORb+vdZFE4xZNot/Bc0LtSXbZmxbUX2ZCq/iNx6GdNT/lVOhsVwR1zqgpVh4h
# RRzkljOK6gz0iBNg2vNafdzUL2yKl9AggbkWNRUMAM2lmFtP0lrDOCA6bcHRKLG/
# U+vhs9gMdlUM9NZev2EKuwk+bjjS1GoVMmc9k1kCgYEAkUjoiooNeS4WvYRNLZak
# laiuncyEASeeiVgdUbv46Po5ER4L2TicHdY7YsuX9iA8gmEYuDbVwAX1fcSLsivM
# IG02tcQ9YRQFapuzcuAADjTLm+wTVJQ0bwT/hwixnQ4X4ThUYKmUi1Tg/9WSWbuB
# vpw57Bzd9UNnaYkyysdbtTs=
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: f6e29d780a9d32447c6f274472216374c0f748cd4a37b6f7a2a84749c2ad1334
# CS2 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAogc+MCHEWXPnWuM8InRq
# MNepFbkW8Jhc2fnlmgrM/8fIkKUO0aSNiTmG+A4rmvzvvnNpBguz56bBaa0BW6vq
# iFKg/r/sv4yCtvsPIsiBG6sZaUID8QlsskxX3207loq0fbex1LxISWmOTW8t7ip7
# /2QFrBJ1vHXjTJ3RZqvxcdKifQhCCt5FCEVpY3ev8lhxWDbflKhtI5K/NGYC3uU/
# 3uZlJ1Iy+yqBxmkYqBJjqhqEKbd7K9P2Ju4LtiAtOwVGUZ4zU9GkG2AbSsabTCpO
# hI6FeGNIYdA3MsUf3BG+sdMXnP03s/UnnpzYFubGydWTOgHccN4nYGE3IkhBy6fn
# /wIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIEvAIBADANBgkqhkiG9w0BAQEFAASCBKYwggSiAgEAAoIBAQCiBz4wIcRZc+da
# 4zwidGow16kVuRbwmFzZ+eWaCsz/x8iQpQ7RpI2JOYb4Diua/O++c2kGC7PnpsFp
# rQFbq+qIUqD+v+y/jIK2+w8iyIEbqxlpQgPxCWyyTFffbTuWirR9t7HUvEhJaY5N
# by3uKnv/ZAWsEnW8deNMndFmq/Fx0qJ9CEIK3kUIRWljd6/yWHFYNt+UqG0jkr80
# ZgLe5T/e5mUnUjL7KoHGaRioEmOqGoQpt3sr0/Ym7gu2IC07BUZRnjNT0aQbYBtK
# xptMKk6EjoV4Y0hh0DcyxR/cEb6x0xec/Tez9SeenNgW5sbJ1ZM6Adxw3idgYTci
# SEHLp+f/AgMBAAECggEACoPH0F3QnTF9WROYCnBdl8/XBDbfuztYAzlJYibDSPIR
# HPnpLUete7NFBAH/aG5zrHtW3HKT+TuEH7R/exB8Bt693epclc2rie5e/BXg8we2
# fXMwSEshR6zWowQ2sr1Lm0D5hGG3mzQDbRkC9QrCwz8dcx47j8BiwM0ZEr2jzIwR
# WlL6ysHv+7MI59m4RqAK+Kn/xsEcH761d61Lr+0zVgFwqI7qHjYx+GKN6jXnTk1S
# 2nyL2NNUkvfnZSrGL/eoKKnu6T0fPr2IwrdeDnct7sYRiJDSQjoEdeXddS4a22If
# BiPOLHup+P1dAvwpK1Yyl/bInnI95wLm8EeP7dCM+QKBgQDLyiZTp0ad/qoSSLNk
# CdR68afUrcXQRVf+ZWy2YikhsGzwinkhUWMU6V+AIYv8PA6nNA2BJt9pgwgZHWYt
# COyAcT9J3gwGMzyLXT0eV1cYVCVYnNq5/RxkSVX+Ri6PgQYOMkBRqiMoeo1chF7E
# DebYxkQgop51a0+nI+cS8CG3qwKBgQDLihysIfA2Mqg+yyd8lV66ObeGnOpDuzUV
# DiFdgiiwnkQVsFDfRjOFREv4bUFFh2jpblOUc6OgTieoA3Au3FTWeGmIDsexx1jc
# 5j77rBkSUSfY+IZmXL2Io5dCJad4iUkhPNIwHkut11rIqI0tj7qbBZDLcSOQaifG
# 0YF+eEws/QKBgCISORgxVlgh9LM73moyTokDkAi5yOHKRiztLiDMBo5wXbZVoGzW
# m5cqcWINucbBD74asMtQAXg1hQwV4zhSTqAmzur9qcr7k/rE6uwAtDoID3piNxtz
# WuTVcgAiIbSyYJ3M/v3oURp6atn185YZsOe7NjaymYWOHHIYSZDb/vcjAoGAK0zI
# aL4XkhAYxrMFRXWpX0ikCFkdZSdQVZhZ9MCZ02j35v1JVxZiI3myB7mGZzo1UWON
# GEm5h4LY4N9KYE2zJqUbHjy2stVLzEKXJ4cnFkR5i6jjPqeAEq9qoEHObNAX5KBB
# vsbTJrpnr8RbtFOdSRlYAk+hVzmeGKe9OqBw5CkCgYBH2+HA+lpRieZaLkzigTqr
# kONnH14GIz3frW2XGjYWnOO4+X65K9PcylRuMxDZkfrrd26tUnp+ghK3UGItsZug
# MTQ3Rv3BgotI7SdlWk6USzw8m4HxupcmdsWB3XzUrAHE75ORZJdLEW4ra7VU+bBD
# Y9XDvjU9z5gGPsymxugwzw==
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 92313e7a495c31942f30f2976e3b509e38e92a58dbc4ea84105b6ff737a77f63
# CS3 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAsAKgkI5rvniIhsooY+8R
# LyCjoUoftgVaYXQQWNOn6ZSM8AFo20ved26JyKfVCHpn95qfGBTPAHcocPiS009b
# qgFA6VSzuEkgU+UEibq3IKxg7LzvxE5Jy6PQm/kr1nUExldIK+Zcynd2QP4foOQp
# P40ruo7jXZFKqr1Q5l7RShcn2B+f32P9UWnPEWBiz2f4Vst5Vc9nEvbQ0aRj+bNI
# vje+FJWGM/suZ4OlhmABgU8C9swj2ETNFHB0lCjY/6Ad1EdrraGqm9Bo/CPPTUCj
# fb2CiMsOYhxDd+bxRMhGPqqnL1EIKejPDGIXzmF4i/KOoDSP+vDrEI/OJAwP8LBS
# YwIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIEvwIBADANBgkqhkiG9w0BAQEFAASCBKkwggSlAgEAAoIBAQCwAqCQjmu+eIiG
# yihj7xEvIKOhSh+2BVphdBBY06fplIzwAWjbS953bonIp9UIemf3mp8YFM8Adyhw
# +JLTT1uqAUDpVLO4SSBT5QSJurcgrGDsvO/ETknLo9Cb+SvWdQTGV0gr5lzKd3ZA
# /h+g5Ck/jSu6juNdkUqqvVDmXtFKFyfYH5/fY/1Rac8RYGLPZ/hWy3lVz2cS9tDR
# pGP5s0i+N74UlYYz+y5ng6WGYAGBTwL2zCPYRM0UcHSUKNj/oB3UR2utoaqb0Gj8
# I89NQKN9vYKIyw5iHEN35vFEyEY+qqcvUQgp6M8MYhfOYXiL8o6gNI/68OsQj84k
# DA/wsFJjAgMBAAECggEAVSJYLsOsqtsbUnMq+Td0DOMRMp0rXHwXXObqV0S9RbaU
# Oyy7XsNCTmt5msRPP0QR0MqJ5HiALb31IjuhrTMH5+GmV5YgPeWlDN9MBCB7noKy
# eR/kK4Qgnq7UYvUxdpBwaE1ke9N3k3kYClTA0K47o2ExwxGFOUdjIdXjcSJwwhBG
# pPuBKOOPGewsCbUQ1vSa6j+8omJIY11HyGZAsO4b04X4zwL5z02ElDsWCWt1TwTE
# JATxKnt85JsdS5HS7hJ8UH+/UzDm5AeFj2RJ1Od/6jZ6Cqqm8geoLHbvRTSigVMe
# ygLZWCoLGP2rNbPtS0EvvE+eaZA/M80Qor1ljap/1QKBgQDeRyUrSexdy5Xlwaav
# 0HtqTQTOwaVOpLMcUNFPjnwHJWQbNqE703C5gsmNQmEL9SU6apy/Y1zV0qnNMEbQ
# GJlRNPx36UxcA8919VQDHNHkdgNZmmIsmnYfX3JX2s/a0JqmCdyCwBoWGKfOfbv9
# 7OA6cpPikCQ5q2kq0srb3YJ3hQKBgQDKtoioWtjYHDzwHcV+W3k8qcb/lYSPCxuk
# ykxXfb9aKqlrzluGgOXoiZXy/+aILkCzikATWgU5wbSMc6RY9YTy5t5RRgRpIrPv
# +oqsumv4NqYPpQoFsyGpz2quJLujolDzDpRI2j1/IgENptrYGgz0VY9O+x0OuBd2
# xtWntlrixwKBgQDAoo3e51D2tMJy/RIVmqvqo1cATKiT8H7dkljkBssMcmZAg2bW
# b1dpHqTITHfIoisiZlT0NQu2r7zC/AzSug7dZvtKfKDVueOpCfVGQUrSIUij9f0R
# RMgMRm7VHug2bcUpErDNi+jPr4x2k1dCKHDnlnb9ygfrBte86jQuudkg9QKBgQCh
# 0ndjVip20ov+7vVCeolc2Pdn/pb0jdyCf4/T5ClGNHpM+k3sIKfoKzVN5+TDX5D9
# AmdGS32SbsTPvl07OrvoIE7nOGq69x4He80KOEOKwS1tncVTaX19DnxOCjrUVPYk
# IcZUJgwjmiSXHlTjYGBpCIg/d4zpvCHXCsFygcsp7wKBgQDRbmn6n+lORR5uclA9
# p4WEm3ISh2m+VLlA9J4EBNWoJtfZEjdvtjVZDrT6BPQYtBU0G9f0rixHM+1jha0w
# K0kk+0JSfN3owwG1s94t9cILcesslwJ8YL08gjEP9EGLZdoi/HX9EJyToukXOyHi
# 6RENy5+LF0dLbWcar6ZchedqNQ==
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: a7be165bcb728343f6949c6f59bbbe5862073e75befb6ea30958f20b862351e0
# RSU1 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAyShZv7IK2FDeu04VwCyH
# IY+gdsGQLAlxyBhy3R074AAM2d45+Gic1Mg+oYwcpmuazLRnD6YNho3j+n4dWEP6
# zjjlIJ5/XX77en158lRp1j1412OefQIzIhERHyRtwcEGvvxxnNBTSMG4EVdUCsow
# wSpAMjYItYQSH8pMUatrsBH0sVTlxrY2waGc0f8jBir6/8a1vWN2i0dOmvKOiYPW
# woPUE08aF084NznuqhLd4MP8XPqf/1S+P9k6+gvG4lm00hBnFR5R00/I3JF0YRCf
# OcSHTkZQbtMcaPVOSE21JO/6fv8hRs9Fh0k3Ov0mD4ro63iEpStn5OaeBDYh42i9
# MwIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIEuwIBADANBgkqhkiG9w0BAQEFAASCBKUwggShAgEAAoIBAQDJKFm/sgrYUN67
# ThXALIchj6B2wZAsCXHIGHLdHTvgAAzZ3jn4aJzUyD6hjByma5rMtGcPpg2GjeP6
# fh1YQ/rOOOUgnn9dfvt6fXnyVGnWPXjXY559AjMiEREfJG3BwQa+/HGc0FNIwbgR
# V1QKyjDBKkAyNgi1hBIfykxRq2uwEfSxVOXGtjbBoZzR/yMGKvr/xrW9Y3aLR06a
# 8o6Jg9bCg9QTTxoXTzg3Oe6qEt3gw/xc+p//VL4/2Tr6C8biWbTSEGcVHlHTT8jc
# kXRhEJ85xIdORlBu0xxo9U5ITbUk7/p+/yFGz0WHSTc6/SYPiujreISlK2fk5p4E
# NiHjaL0zAgMBAAECgf9PGY7b0nxxPgZXoQeXNJXunIvSJvXfsIG4LTpTDdZ9lDIk
# JJP8b9E72tdwrv0/yRBrboUYTN5aCsbwY/x7Y5U8LSNBsGcPsjSGoNCoed55tbJ5
# qrKnyuBQhRA2hBykvpfoggbVoxXHhmWFwXv1bOG/E4jVixSMTA1/HWLlZS2eDhM7
# sk1stoTbVn5NEuDhZXnfV5fxMU/TuVSr5WwyBW3WTXgK7u1/nr7rEbUnponqXeed
# I/4OcLkF8MUOXCHiOGcJZ//d2K8eHsybODKVYAvGUGEYxzpgfCSmVbe5zH3/uAi9
# OjTh8peDAhfoucgSUv7V0DJvp30oRkM75vi5s/ECgYEA/e7qA0aviOQUrpfly9bt
# MLtxTCnyzQyxGIVdJKD95BUVXSwTZZOZ1pfK4u6E3vOZpvq8Bv2CFAH8TJ32SQcG
# DRhHtkCsuwH7An4MFN0S3Z5J8AACGeVEPsGDOPcPnay4jmXTcQqml3y3S5aGpA4n
# 0vPco+tI2AEdNDfpn51IkYUCgYEAyst5oOukfctD/LVEHaib0uhmB16Ud25jy/dW
# cib4fg6/6U9SqvCDmDNmrDjyzStJTqbKnnCd0plr3kMr5lmVC/I3pR28eu9/Xsys
# BHeDyNr8vhooQtuqXU/EOMQPwzdBgqsnloZc4JTpY2BCvQLQRC8x1ettxcXfO5Pu
# vbX/9VcCgYEAnKzwjhzq6Vdwu1jVXDO8HTlJ6mhnesS98Bc5JQSAIl4v1FEBlsa/
# QHxfniz0pms+/pvtr5Jy08110gAUmXJP9XxporW83ZWXPi5vXeAZZ8vmasJWiYu/
# 08iqIlettud+571D/JdJumYk4ep6IHbrc2krVagyRbRKRJHK/8SXpdECgYAXjE0R
# TIuLN+ErJPlF4GBHu0itrmPbAmyAMLZPBwtvx9KtCtL0mn0NXVqcwPggrtgSU/fP
# MhCBdeM6qd4dH2XZP0UK3UsXk1vc7DNFSYN5/UO/51WpfcxojWyhktKpvm7S94Df
# T7bVNTVsnq7hN8RrRneo+W+DuZhUWLcuPEX+fQKBgBtmjiMFTTQ5ZCRxO6NcuptC
# hJvkxwSLyuNAZNiwLQdLWHc49kRCcqwjAqY/duevqWUf6q9Xl2kitLS5ySkLy/op
# pH6BVpwkYaub+YMX6ueNbtKs14BZi3/YfIDVlMHCpbgvcyFpZqlX1CbkeCLPVPXC
# GvA3PWbsk/emV/iy3P0X
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: fe546839a617497916fc86efb9b790eb4c2f5738bfee167ba81770fa33b742f8
# RSU2 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAn1Ehp1iiMaMCrD0Yf592
# 5Sc+a2twbwftlES043fv1Ne/jzDqHNqYu710XOvpGGz0iTqzkMCjnfVxZ7x4LDxr
# DBgxeh1FbDZbH1dgNO+UaqeJ66H0ooHdk5VZjH5Hu+uArNCYn3Lv9z5E0EqjtoLR
# F/6pPxbfmbwVlY/9pcjjXzpf0ukKf+4zYwfgEEXK6C83zZSL/O32A20N7moDTjFP
# MBj9B/bTISA3fiyZnizouRlpb4ZEBdHb+66Jmv6dBDjJFTpARdGXVsKD6w0/JbI+
# gl5192hr2lvZrKn39owNX/d6cXdiRaDWO+yEgsL8vaOfMnXEApV8YI0NgchylbFy
# LwIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIEvgIBADANBgkqhkiG9w0BAQEFAASCBKgwggSkAgEAAoIBAQCfUSGnWKIxowKs
# PRh/n3blJz5ra3BvB+2URLTjd+/U17+PMOoc2pi7vXRc6+kYbPSJOrOQwKOd9XFn
# vHgsPGsMGDF6HUVsNlsfV2A075Rqp4nrofSigd2TlVmMfke764Cs0Jifcu/3PkTQ
# SqO2gtEX/qk/Ft+ZvBWVj/2lyONfOl/S6Qp/7jNjB+AQRcroLzfNlIv87fYDbQ3u
# agNOMU8wGP0H9tMhIDd+LJmeLOi5GWlvhkQF0dv7roma/p0EOMkVOkBF0ZdWwoPr
# DT8lsj6CXnX3aGvaW9msqff2jA1f93pxd2JFoNY77ISCwvy9o58ydcQClXxgjQ2B
# yHKVsXIvAgMBAAECggEAE+cORboltP67bZSfqV3cprRC23zgtGDbVgZJShC90NX3
# s9CKsU/A/H8mo28YlQ5oyXX1tb54Z4TLMIg+blmejom9MJdUiLgM+nraEB2NPyUD
# 7qsHr9TPv0lNQRG2Lhc1tsvDrUkDX7HokH7VOePYxt8aT0ExGM2tgpwqNe+ahqxG
# kaQYM87ZkdsNMOY4NYbN28reE3LYKNfo4gOql9j9arwhCnC++Kg5V4VZxlD6J3W+
# Xegg1YuUWhIsFldCJSRRik5VYdo2QuyTCZhmR1CntdhFfLnaxfVIdXpxxe4H5tqz
# JZBGiLohrv1tSB6IHeYAWb8/xM1Qg0vG7IXZXpTpyQKBgQDNwsEvvqAsy/ACK+cI
# k2wA/vCd8KBrnPzY5eyZWHFv9ALo1vG9XNKdyIKYkGGIA7eF5TeiDlsaPfMFtlud
# 0QGr1x7CGSJUmZcek2Ul0fmHol0kplt80jDBaEatZq8RTBQtoZvMHune925dR7lg
# h+3aMq5ARJjOTiiHi5TUFrZbBwKBgQDGN13NfWoFITptZ8X9DlR4VRkYzDsqwn2O
# kp83igWaUTY8LSuK8scOuraPQJpe4EaEyssUK1NH33RqjgnRgnIKBN/bqVFU+YB9
# Kzs55EG+CRZV1cDo42fCF/KvisnJMR7nI7o1qXQN4ETMZPLENE9Hhtcd+N+TKBwm
# mruekODdmQKBgQCX414sWnFu4BSJ5dKkF/8wNQF19XzWM4rKqd+fyxPh6qSDMLg+
# atjmtG8DJAF7IBNHec85h5NkqbpNyzGSLAkpyqDf8yHOhZpybafK5Vdn8kkDlvIO
# EDMBcnJJ6nTtNdXnYVbatS868je8EAgd4/mGisbqljiegj+U30q7zRBL3QKBgCea
# TE2QLyyTNP9C6pXi1RGtvvPrai7i6P8hYFpSY0gvzaw8QiTi2M6ik3MPr0ghezVw
# 5x5CgcMsbDAV7PRFIc/KpYdXzv4xU3CuwIiSiGgVnLbNnFtrhAGNk1lrW2GtRMVd
# qAissJlNI7HKwY5d/TEHSdedL95Q9z7nT3Eg9SyRAoGBAJihveYWEDE/KpczsjLA
# G9FseHhF4XM4aVRCRJIk+mrXnDrf4yEqQRztK9E7vEJYPJaKUwEEiLGCiPNvwDj/
# zyItiC8MZg+rPppY0sC0ycVYEVKDp+8PjfVu25D00unhVWvF0ogOAvM0IGrV/ZKj
# 61flYBdZ77tTF6sDP9azwnsc
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 6782a9c7456c05a52e727d3f52f604c5c5bbbfec762e7367ad1ac02169517637
# RSU3 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAsEJqLldyFff3iUSeHq7E
# +yANHCvmyliDnU1KRd8ljkrnMFcpa6EQo/aw4WfBu0+2aDkLxBIZKWRf6JUn84Cz
# wBtaU+m326O62BlARLKXXOqvz786QOm6d2/LXpaTKs5PZGRfBkbW4MDR60C0006y
# 9/TsHWwikdlSRod4YEhLo332D4ZM7J9EiXKmge6KOnHKljuPpXsEN0BuSejXl0Yd
# oR3K2XJDKSZY5JDTpJUIZgczd6SUrYeJXYKKtHgWTyo+PuPIVSz3s3n4EDACWE1O
# 8quGgGAjYZkQrBPwoOZLYe41L0WJ4nHXB6HcNOVKks8VKlLSsKxssuP+f5xhbWLr
# lQIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIEvQIBADANBgkqhkiG9w0BAQEFAASCBKcwggSjAgEAAoIBAQCwQmouV3IV9/eJ
# RJ4ersT7IA0cK+bKWIOdTUpF3yWOSucwVylroRCj9rDhZ8G7T7ZoOQvEEhkpZF/o
# lSfzgLPAG1pT6bfbo7rYGUBEspdc6q/PvzpA6bp3b8telpMqzk9kZF8GRtbgwNHr
# QLTTTrL39OwdbCKR2VJGh3hgSEujffYPhkzsn0SJcqaB7oo6ccqWO4+lewQ3QG5J
# 6NeXRh2hHcrZckMpJljkkNOklQhmBzN3pJSth4ldgoq0eBZPKj4+48hVLPezefgQ
# MAJYTU7yq4aAYCNhmRCsE/Cg5kth7jUvRYnicdcHodw05UqSzxUqUtKwrGyy4/5/
# nGFtYuuVAgMBAAECggEACP9FjvAFHCdNihg9P1u0emJ8c3+vhuIAdeXIG3ZJ4yWM
# /46zcpGvg8RylaRHjgQs+iJPU3GJD0UsZXbs/yUGspEINK2te5depkFDt+irM/cB
# hR1ByqZ4+jfJWHQJ4cQo5qWo+W0MSD9kzRlpzDosMIletBxyTKJHQjUQE/ocwk+f
# O3y2M1y3ok2LhgNl59n6jPlOiY6Wy+qGThVkyiWIHpi9fm3dMRJeoovfKLYWVzr4
# jczJZVFuTyiHKPFGKp9Vm29X5xeZYzF2VpsecAIM0YgQTZE5kerNAKNWJyQvTzH6
# /hJdQjHhzr7Dc2mKiLmeWcUK8P/z6FjJq6mcUCwHUQKBgQDsvTZLtrqggA/p6i5G
# WBHktGgo9ImslJb6uhshul0TLrTGkTp29EwMm2g+1X86xoFaTCjHJplh8NJDccC0
# IToXIGb7pgltJFxDrRGH8aVV6nbGyhAN5MpfiOos2O02syEIBWqcvSlpNFbJpFvt
# 37J4K/gT88yDkGmZmwaZJtWYjwKBgQC+mYkdrAcaQ/bZtLV0tpyGj81rKmCiB5K7
# cr9O2FhjnRibqP57/PjuJDwkoWGVgaEBae1TIX9gAfMIzl2ptlfM6hJuHhYjZPZo
# Kd6GnBV+HVyA1lYRXq3riwGoCu58ZT0+tYk/2fJQMBlrKqHNlBUIEpp2CUebxV7/
# O+DHOIwjmwKBgFONbA5IzZE74WHzLqXRC2+mZGSf+b8ZKjgPWugKeDL+9vpl4zZ8
# fiKs7pvOifraeGjAHFw9OUEh13PKP/LTD0d+PhpuvUDx5kZUXK2YEXxDJex/AC+H
# Ig2ZqtxtKzt0+SF1l+z9rhHdUQwVoARSQRC8o++WygVdAIgf+LIwzI3tAoGAOCNy
# zmmH4gWYpIDkXU8YBU4/u8vMkIzYfBuNG4T/a7+uqtJ4uj5Fd6b2i/d4jZeTu53e
# h/i60qVgVvype744WCOtb/+ul5g6N231nAJHFlFBmLUIvq77XQAhacRmf/81rc28
# cjEYfOPd6MGyzKFMHIeWNSQAknHszBJv313ZcPcCgYEAjqsopqVphoymoGgcwqYw
# HT05oIlHx5QJeo1Za9DVYawvff/AHlQCuzvM+ZWZvD/KuWeZQzgL/T4s62Ymc8z6
# clygVqbJIXW1LvwiXC2sGI9ddOoQz9lyyR9gwRBFFH085YuSv9ZwcUTHFXnKJq2u
# bUR8abA/mGIGwRsdggVYeKU=
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: e4685699bdc49681fdfa782e939870d8baab30eb8b23d9cb9b7e935a5b20ac2c

# %% [markdown]
# NOW WE WILL TAKE THE KEYS PAIRS SIZE TO BE 1028 BITS, WHICH ARE Medium-strength keyS.

# %%
import hashlib
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.primitives.asymmetric import rsa

class UDCSystem:
    def __init__(self):
        self.evs = {}
        self.css = {}
        self.revocation_list = set()

    def register_ev(self, ev_name, ev_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(ev_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if EV identity exists in the database or revocation list
        if ev_name in self.evs:
            return "Registration failed. EV identity already registered."
        if ev_name in self.revocation_list:
            return "Registration failed. EV identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, ev_name)

        # Step 6: Store EV information
        self.evs[ev_name] = {
            "public_key": public_key,
            "private_key": private_key,
            "pseudo_identity": pseudo_identity
        }

        public_key_pem = public_key.public_bytes(encoding=serialization.Encoding.PEM, format=serialization.PublicFormat.SubjectPublicKeyInfo).decode()
        private_key_pem = private_key.private_bytes(encoding=serialization.Encoding.PEM, format=serialization.PrivateFormat.PKCS8, encryption_algorithm=serialization.NoEncryption()).decode()

        return f"{ev_name} registration successful.\nPublic Key:\n{public_key_pem}\nPrivate Key:\n{private_key_pem}\nPseudo-Identity: {pseudo_identity}"

    def register_cs(self, cs_name, cs_timestamp):
        # Step 2: Verify timestamp
        # Adjust the allowed execution range according to your requirements
        if not self._is_within_execution_range(cs_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if CS identity exists in the database or revocation list
        if cs_name in self.css:
            return "Registration failed. CS identity already registered."
        if cs_name in self.revocation_list:
            return "Registration failed. CS identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, cs_name)

        # Step 6: Store CS information
        self.css[cs_name] = {
            "public_key": public_key,
            "private_key": private_key,
            "pseudo_identity": pseudo_identity
        }

        public_key_pem = public_key.public_bytes(encoding=serialization.Encoding.PEM, format=serialization.PublicFormat.SubjectPublicKeyInfo).decode()
        private_key_pem = private_key.private_bytes(encoding=serialization.Encoding.PEM, format=serialization.PrivateFormat.PKCS8, encryption_algorithm=serialization.NoEncryption()).decode()

        return f"{cs_name} registration successful.\nPublic Key:\n{public_key_pem}\nPrivate Key:\n{private_key_pem}\nPseudo-Identity: {pseudo_identity}"

    def _is_within_execution_range(self, timestamp):
        # Adjust the execution range logic according to your requirements
        return True

    def _generate_key_pair(self):
        # Generate a 1024-bit RSA key pair
        private_key = rsa.generate_private_key(
            public_exponent=65537,
            key_size=1024
        )
        public_key = private_key.public_key()
        return public_key, private_key

    def _calculate_pseudo_identity(self, private_key, identity):
        # Use a secure hash function, such as SHA-256, to calculate the pseudo-identity
        hash_input = private_key.private_bytes(encoding=serialization.Encoding.PEM, format=serialization.PrivateFormat.PKCS8, encryption_algorithm=serialization.NoEncryption()) + identity.encode()
        pseudo_identity = hashlib.sha256(hash_input).hexdigest()
        return pseudo_identity

# Example usage
udc_system = UDCSystem()

# EV registration
ev_names = ["EV1", "EV2", "EV3"]
ev_timestamp = "2023-06-28T12:00:00"

for ev_name in ev_names:
    ev_registration_result = udc_system.register_ev(ev_name, ev_timestamp)
    print(ev_registration_result)

# CS registration
cs_names = ["CS1", "CS2", "CS3"]
cs_timestamp = "2023-06-28T12:00:00"

for cs_name in cs_names:
    cs_registration_result = udc_system.register_cs(cs_name, cs_timestamp)
    print(cs_registration_result)
# Out:
# EV1 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIGfMA0GCSqGSIb3DQEBAQUAA4GNADCBiQKBgQCvGwqaDDUxWpW6IXCmTS+qq1k1
# FIPDVcR8FMibVxz6S7tZ6wJlTp6dTyBdkkdAcITFUWC7vejMf7r074VQGxkqgaDP
# AZs/uyEWQ4o3yBrwadnnHJsPLcEOOSxli1S4IJ/1jUSFrSFSbl6zeJYCa8XHB3eg
# Ri4K2Wf/eMeFXLBOHwIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIICdQIBADANBgkqhkiG9w0BAQEFAASCAl8wggJbAgEAAoGBAK8bCpoMNTFalboh
# cKZNL6qrWTUUg8NVxHwUyJtXHPpLu1nrAmVOnp1PIF2SR0BwhMVRYLu96Mx/uvTv
# hVAbGSqBoM8Bmz+7IRZDijfIGvBp2eccmw8twQ45LGWLVLggn/WNRIWtIVJuXrN4
# lgJrxccHd6BGLgrZZ/94x4VcsE4fAgMBAAECgYBRUAxXRq340ijPOzIVd6hX56PQ
# O0uIjK5mNDyHric9r6c7dR8yrhSH1jOgYAoISXfOLSDvbZvKQtItZYCRl1PSnX5x
# lNZYeJgJrWoiUsei82Bn/G4+/s0rcvEkGl3rPB8vKVlkKH+zgHSeu2Bnp4QE3jwT
# b2vIGocDOHKbQdI5WQJBANxUnUIlfctlRE/1oFCHT9b3pNgyUQDyj5SKUN1VAMeN
# 6ENAtPl1nAxu3+kwFRA6k2gplpVJ+NFfK0JJDH/bYD0CQQDLdCAFiCstszQ7iZ/u
# InbEMy2xatNQVCqbaKCBvDSZ4X70dgUGYMD4y5HHaXfk6cYODFoYqr0glFnod2zn
# 2xGLAkBqOumvcMAcBvFO1BC9gt/9t1zlWC0yFcEgTyf57vf3PvZTJqma9ReN7w9K
# MQKW1ocn25Vc2VN8LzR+OxYpty3JAj8UqbaW2T2JZqnnYhLcHKPzST9axX6wqdup
# 7PZgNr0g48YBDft0ql7u5b3ogs2qchOrWZXM64pJxMdc1MQ6yAUCQQCul0HG3+1R
# vBZ1RkaQfGkTXJWVCfBNNs482+sn24Ev7bK9/iT4odpPRX5ZzCJtjtk/mHMYRefp
# 6mubOzLhMOrs
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 9fc9fc8fc22bd79e8004d68c5f28a91dc4e0adb3be4c840c088152dbe4d6c46b
# EV2 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIGfMA0GCSqGSIb3DQEBAQUAA4GNADCBiQKBgQDjQQlVp4qtUwQBPAQ1sy3Q4Fnw
# xEAIxnVYuUuxTLkxt6s+lDzt5wynOiUhmPuHvniQIOWNcYwwCica4syLgHMMG341
# VRhJbFE119l8bEJT94/UejU+tV6cYmiWwWSS0+1KTcDqS2++p2TL4KEV0th89b6C
# olrKcRlIj25npMVOtQIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIICdgIBADANBgkqhkiG9w0BAQEFAASCAmAwggJcAgEAAoGBAONBCVWniq1TBAE8
# BDWzLdDgWfDEQAjGdVi5S7FMuTG3qz6UPO3nDKc6JSGY+4e+eJAg5Y1xjDAKJxri
# zIuAcwwbfjVVGElsUTXX2XxsQlP3j9R6NT61XpxiaJbBZJLT7UpNwOpLb76nZMvg
# oRXS2Hz1voKiWspxGUiPbmekxU61AgMBAAECgYB+NKQmeYE+eJgEx3vfBr8u/Sl1
# 2MdnGDAbMeyjbmR7A/GKM3ES/fm89UGhwwANhu4VvO8++gxMsZa+C65k2tUInFwl
# 3txQT2ossW/tv4w0c7fi+Lw0/4uvE+RZl9wG3JiLgLvWUPCigdwqixxOn5utG4XP
# Kckm85MPceCc+zDvgQJBAPUGtQtHJkCj9XeyZiokXX11u2D8C871ga/g1kuZ07P7
# Q+G/NgdTdyUM7dWTc+ieR+dp384V6acXM4yl3baRshkCQQDtbpEQUmUtWO4jzH+D
# zGZJLEEaISjNI/yC9UVP2srhfW7gxXlRXpG2LVpDnNPFTFI1nViVeDgdagT+2BPL
# DCz9AkAj/EUwj9V9XtcZKjk47ThRya2oU7wEPCg8xV+ToNbnsvpIOEXeE5MG/Pwd
# BtfaDQzwXqtA4BT9tjma6W1Dd+hZAkBFQTb299GjRIlRz9hx7TD4rvveT0XDcHe7
# CyfIfx0mYJvy3Cbi4R7HcLsfdaMfrX9dPCQWlRZpHf+PBh/f3hFRAkEAmUE+QMgB
# gDFVwa7HL9HiuMbE+zdfPYwuuSabDWHY4052/Z/dnBPEewgPn642UjwsnC+RxsC0
# ZxAeBM2qKIOPSg==
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 5561a111d2d742861d62f51433a26801018f6f63d734c175d81cc38f486354bb
# EV3 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIGfMA0GCSqGSIb3DQEBAQUAA4GNADCBiQKBgQDlssikJ22I5BF3ytlL4OfAcOa/
# P/E8b1FgFSrSlZ2fZci6GzNC1GSYGsVsSazWOUWRPRYCy88Uy+Eo6uRfKTpVrD0/
# HMxWq/iVtPQDjxyAuEM0iIJf3W1h7O928zskn0C9yB+5WGSD5ff11Jgdu1ChenfU
# LaVc6ZIkRgwZB+iIYwIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIICdwIBADANBgkqhkiG9w0BAQEFAASCAmEwggJdAgEAAoGBAOWyyKQnbYjkEXfK
# 2Uvg58Bw5r8/8TxvUWAVKtKVnZ9lyLobM0LUZJgaxWxJrNY5RZE9FgLLzxTL4Sjq
# 5F8pOlWsPT8czFar+JW09AOPHIC4QzSIgl/dbWHs73bzOySfQL3IH7lYZIPl9/XU
# mB27UKF6d9QtpVzpkiRGDBkH6IhjAgMBAAECgYBemY42xSJAgaWMD5gEvyDTSexO
# kdgZisMZ7j3PstzS3AmaVD99Y5n2ZvguC/3J0JaNJXpeNnAX4Yve3Tam1oT2IfUT
# AV9Y5jMQ9LxGwQJSDxLhEtodWzm5J7UCq1UJaGb8oMUXXxyjgLvQI7clBI59Y8lH
# txRGvwBqYJ6iFgOh4QJBAPt5DZqzge8A8YwlLdx3eVN+h5prPLYeTv1JWPELK4g+
# /Bqn0wRb8OaAdta9cWsOjm/cgiEfRemE2Ec5WzNYX7MCQQDp1WFCVn9hc0qDL1Yb
# kpI1Be2vKt91W3UR1Hl+gWHVh9c1xlr37ZM41h22TKI0qZccyrq/GclPESTe9GfC
# slyRAkB//KVi5hesV9OYG1gTDC+QwiYr/oZAvn4/RTRiQegfCMdwnZe1cUHTXvCc
# 7IAsF5WA8z67stn3NuiIn3V+VW0nAkEA4eURoFSPmkUWpsUEGn7uX+rqQ17XoThJ
# UIBDHsM/EFm6vmhxWTJaF35CFerSiK2NHnN7FUKEB644QGs8EgrdAQJBAPmE2SGP
# Y6FEkEsHsaOTtdt+LUgf+XqVtSvLbQKbw9ZOro5hi2BaEDNzSKaz+D/qcQNvQlop
# aTsunCxB90UvTNk=
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 1c289530cdaa0daa9301d960fcd8ffbbe6865c547668cb9a1c57976f3803ec68
# CS1 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIGfMA0GCSqGSIb3DQEBAQUAA4GNADCBiQKBgQDjnk/bUoMrkkfDen5P1FIRPsGb
# c4GWPjBjPsOH7ptdd65brOkU7qy6hxj3O1ckD4oTAbU4qZPQ1kkz6MQ+f5qZ9Pz8
# pLpBedE5frZaCvKrSs+TmP0ROdV24+A6QAWMC535WesDQU0PE3hlTWlz5Se8aygP
# zMxy1cckDsN51NJkswIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIICeAIBADANBgkqhkiG9w0BAQEFAASCAmIwggJeAgEAAoGBAOOeT9tSgyuSR8N6
# fk/UUhE+wZtzgZY+MGM+w4fum113rlus6RTurLqHGPc7VyQPihMBtTipk9DWSTPo
# xD5/mpn0/PykukF50Tl+tloK8qtKz5OY/RE51Xbj4DpABYwLnflZ6wNBTQ8TeGVN
# aXPlJ7xrKA/MzHLVxyQOw3nU0mSzAgMBAAECgYEAjzblwfZpp7mTQ7BH10ydElKt
# GHUVnQWmBlvQRS/hO275Gp9xzATcU0R7dds1WfAZDRpu/qbb5XNefbW//B7nkzUe
# 0LowAtRP2iK3wUQ2D3Urxnl3pdvYiIzCNhk4TUmEYrfOB5Lcjeg3TpQa+y9QaBQ1
# SJzgVaGZrQ8p5md4ENkCQQD1Ts/X7MJSV+fV7lJjkVCUphSC+koBdr7xNu7AtP0J
# h2dwe5/eXTuF4qoKvCnwFG4hbU2D0bx6tZkq3UuC+bivAkEA7YoeN3aXsZR1fxMW
# rAWnQKMenQjo9ZdEhWJMJxkj2PXIShGzzbG7cpVlw12cCrhbk4HGHVdmPOAlIwtQ
# yTeNPQJAMZw8wIhrTEfm5QcLtoM+7rEf2NVRfjZLq3DWnDZ+Lh0qOD9oN4pXbV5H
# 0V/4g0s+cpguYwhZu99aGKckjFqAlQJBAKJPJxiE22BG7gY3l91RO5iKHUf2J6Bw
# jSyLHzf0EK+WOhaKhA7ALDI+bTuSQiZ9FG31VdcEumJMUnPgroHfiI0CQQCnOI53
# RhsOrv8YKKNpCAYA3oKjOkX8zRF5iaUp7Rfud2Mji5txWE00b/mkyCnPfhD4VkLG
# a8XCjuVjcKoJBRRR
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 468ad060484ce44c3df44c8f474a22d699f99673a259d29f0652f3ef00369c5c
# CS2 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIGfMA0GCSqGSIb3DQEBAQUAA4GNADCBiQKBgQC0PBZLMnNODqRtgFRi2xQCBjkC
# 5LKfEvqKxfwCzs06ZpgWAZRgQDZrjQXMnaaLZFY2/MXXiIz6kGlmqXn7TLVO+VIa
# 424G/pM28+MPbjL+R0SRETKJR+LJ6dPGMhbdNKAY5cCW8gnb2f0VRB2XywXAvjA8
# i1DRI7nF3FUNVgeOeQIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIICdgIBADANBgkqhkiG9w0BAQEFAASCAmAwggJcAgEAAoGBALQ8Fksyc04OpG2A
# VGLbFAIGOQLksp8S+orF/ALOzTpmmBYBlGBANmuNBcydpotkVjb8xdeIjPqQaWap
# eftMtU75Uhrjbgb+kzbz4w9uMv5HRJERMolH4snp08YyFt00oBjlwJbyCdvZ/RVE
# HZfLBcC+MDyLUNEjucXcVQ1WB455AgMBAAECgYA5THz97Q0RPMBze3/YabOjrRzE
# 2bYbsmnqYmTq85n1PhaNsHTeYKusZ4n3cgs3d2+dTaEME4JWSkDn/WslRE7DQxVN
# s3zKm8sjbeJu5XEyajNKh51Vs+tPw+vFrhdz2uc1vi2Zg/xfErZE8nVAlleTIIx5
# eEtaLzCIowDCB8FXXQJBANgqNM5Zyai5C8sf39wTZ77WHTJ6+TwgRxR/QOHLtN98
# ASr+tclRLlPiHxDc3VGMGeSpr2ZtkO1g/f60uW9te2cCQQDVctcFYeq8HsOnMpIA
# 7TNiVUFY0JZiBtr3Gb6cFAnkrVfQV2dspToMp/8M2nzSwCxodyGDPexSeam08GoC
# 2FsfAkAa5e2aO8v/Jb+U8AtwHC4NriEF9g1rcOzHXSparnl8UbbnfbhrK6HjKEEL
# XSBhFFjofkDoMvwUvbv9ZMmqVupDAkAvGtPnBS/naialfFyKRc6kMcplDktRwM+L
# 3quZCDcSt0p82P0jFeeUqXJ45LLNU8m5GClWLFE99kmEe9X5YMPjAkEAn1X4srv0
# sgv5BOLHKZX8ynYPmmvAXseuzV374oKX0q6/a87CeWE9TBBcHtMt5EEfvzHAcgBy
# 2JAk9ILFvNJ2zw==
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 838d31d6da026baa1f478f430cd8e5a2fed45e7dc34ac21c14a339b84a7d3c4e
# CS3 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MIGfMA0GCSqGSIb3DQEBAQUAA4GNADCBiQKBgQDYMJXSNzwtwvxklzjFY1hqvpyn
# 6dBdLjedL1/5/fMvypu5iePt4SmzoNItfMJGHogxzCa6tbComaavV+p0F6JwQTj7
# 9pLlOliJLjvk0ycCh+7GgsI+2C7hrBllu5iBU/1SRAJqwloUefoU+JJhXeDtEL4p
# SocRQBIxi6w0YjNNWQIDAQAB
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIICdgIBADANBgkqhkiG9w0BAQEFAASCAmAwggJcAgEAAoGBANgwldI3PC3C/GSX
# OMVjWGq+nKfp0F0uN50vX/n98y/Km7mJ4+3hKbOg0i18wkYeiDHMJrq1sKiZpq9X
# 6nQXonBBOPv2kuU6WIkuO+TTJwKH7saCwj7YLuGsGWW7mIFT/VJEAmrCWhR5+hT4
# kmFd4O0QvilKhxFAEjGLrDRiM01ZAgMBAAECgYAsbW+cj7VSQivUEC+egNf+t8VB
# zI8BVyoep0m1+jYrsBtoeanZjNghDf+jUWwrNMMQWL/sxsHTJCBZEFwiF2lN/53m
# 1yrQTmi7mq/hq3Kr2nnfvp48Jy9NbGmEHaYU/4sbJ5ZQCyIxOlL/zeLJIUKNBVIY
# 0GuXqBgve2A/QuMv8QJBAPIf8KgtWZLJXIsCEfI3CI2KY6bgQlGWnD1GVD3cZGyM
# 8SztpkWevyUEVFwEz5BMThNz7tBoRas/6gm1kahe83sCQQDklCtfF59mTdMVNS3T
# Za/6IZZ5sA6EtFDEYXdj15YRe5SqLOBwhi4W6dnWXTtajNKKpn2kO/123iX8YVWl
# VJA7AkEAwHtr0gbbYrn5e/jVU300q3EM76jwj/PvmTbD2bnPjAwv3su+lzIwOrlK
# Zyzb5ZcDqqtLexqp6A4TfEx/0x5I6QJAKKSj9ZuYrzMlVj8Hb/BD0yEHxYlle3ko
# Z1LBTNJ3j5I+w+eI3Nku9soL/s7DD/28LgUekAZOskUb0f1ooiYgIwJANZx1hJYH
# SssUggGG9rgGjZ1q0UIKHh2fdklQsV8/9N2DEphaTJWRWOPJCW1FIGHbDyTR0LVU
# ihWvBllXxXwljA==
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: d8a35ae66e851670d5911603246642efdbed1d896de1a9a3a22814a79f046da0

# %% [markdown]
# NOW FINALLY FOR A LOW STRENGTH KEY, WE WILL TAKE A 512 BITS KEY SIZE.

# %%
import hashlib
from cryptography.hazmat.primitives.asymmetric import rsa
from cryptography.hazmat.primitives import serialization

class UDCSystem:
    def __init__(self):
        self.evs = {}
        self.css = {}
        self.rsus = {}
        self.revocation_list = set()

    def register_ev(self, ev_name, ev_timestamp):
        # Step 2: Verify timestamp
        if not self._is_within_execution_range(ev_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if EV identity exists in the database or revocation list
        if ev_name in self.evs:
            return "Registration failed. EV identity already registered."
        if ev_name in self.revocation_list:
            return "Registration failed. EV identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, ev_name)

        # Step 6: Store EV information
        self.evs[ev_name] = {
            "public_key": public_key,
            "private_key": private_key,
            "pseudo_identity": pseudo_identity
        }

        public_key_pem = public_key.public_bytes(encoding=serialization.Encoding.PEM, format=serialization.PublicFormat.SubjectPublicKeyInfo).decode()
        private_key_pem = private_key.private_bytes(encoding=serialization.Encoding.PEM, format=serialization.PrivateFormat.PKCS8, encryption_algorithm=serialization.NoEncryption()).decode()

        return f"{ev_name} registration successful.\nPublic Key:\n{public_key_pem}\nPrivate Key:\n{private_key_pem}\nPseudo-Identity: {pseudo_identity}"

    def register_cs(self, cs_name, cs_timestamp):
        # Step 2: Verify timestamp
        if not self._is_within_execution_range(cs_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if CS identity exists in the database or revocation list
        if cs_name in self.css:
            return "Registration failed. CS identity already registered."
        if cs_name in self.revocation_list:
            return "Registration failed. CS identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, cs_name)

        # Step 6: Store CS information
        self.css[cs_name] = {
            "public_key": public_key,
            "private_key": private_key,
            "pseudo_identity": pseudo_identity
        }

        public_key_pem = public_key.public_bytes(encoding=serialization.Encoding.PEM, format=serialization.PublicFormat.SubjectPublicKeyInfo).decode()
        private_key_pem = private_key.private_bytes(encoding=serialization.Encoding.PEM, format=serialization.PrivateFormat.PKCS8, encryption_algorithm=serialization.NoEncryption()).decode()

        return f"{cs_name} registration successful.\nPublic Key:\n{public_key_pem}\nPrivate Key:\n{private_key_pem}\nPseudo-Identity: {pseudo_identity}"

    def register_rsu(self, rsu_name, rsu_timestamp):
        # Step 2: Verify timestamp
        if not self._is_within_execution_range(rsu_timestamp):
            return "Registration failed. Timestamp is not within the allowed execution range."

        # Step 3: Check if RSU identity exists in the database or revocation list
        if rsu_name in self.rsus:
            return "Registration failed. RSU identity already registered."
        if rsu_name in self.revocation_list:
            return "Registration failed. RSU identity is illegal."

        # Step 4: Generate key pair
        public_key, private_key = self._generate_key_pair()

        # Step 5: Calculate pseudo-identity
        pseudo_identity = self._calculate_pseudo_identity(private_key, rsu_name)

        # Step 6: Store RSU information
        self.rsus[rsu_name] = {
            "public_key": public_key,
            "private_key": private_key,
            "pseudo_identity": pseudo_identity
        }

        public_key_pem = public_key.public_bytes(encoding=serialization.Encoding.PEM, format=serialization.PublicFormat.SubjectPublicKeyInfo).decode()
        private_key_pem = private_key.private_bytes(encoding=serialization.Encoding.PEM, format=serialization.PrivateFormat.PKCS8, encryption_algorithm=serialization.NoEncryption()).decode()

        return f"{rsu_name} registration successful.\nPublic Key:\n{public_key_pem}\nPrivate Key:\n{private_key_pem}\nPseudo-Identity: {pseudo_identity}"

    def _is_within_execution_range(self, timestamp):
        # Adjust the execution range logic according to your requirements
        return True

    def _generate_key_pair(self):
        # Generate a 2048-bit RSA key pair
        private_key = rsa.generate_private_key(
            public_exponent=65537,
            key_size=512
        )
        public_key = private_key.public_key()
        return public_key, private_key

    def _calculate_pseudo_identity(self, private_key, identity):
        # Use a secure hash function, such as SHA-256, to calculate the pseudo-identity
        hash_input = private_key.private_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PrivateFormat.PKCS8,
            encryption_algorithm=serialization.NoEncryption()
        ) + identity.encode()
        pseudo_identity = hashlib.sha256(hash_input).hexdigest()
        return pseudo_identity

# Example usage
udc_system = UDCSystem()

# EV registration
ev_names = ["EV1", "EV2", "EV3"]
ev_timestamp = "2023-06-28T12:00:00"

for ev_name in ev_names:
    ev_registration_result = udc_system.register_ev(ev_name, ev_timestamp)
    print(ev_registration_result)

# CS registration
cs_names = ["CS1", "CS2", "CS3"]
cs_timestamp = "2023-06-28T12:00:00"

for cs_name in cs_names:
    cs_registration_result = udc_system.register_cs(cs_name, cs_timestamp)
    print(cs_registration_result)

# RSU registration
rsu_names = ["RSU1", "RSU2", "RSU3"]
rsu_timestamp = "2023-06-28T12:00:00"

for rsu_name in rsu_names:
    rsu_registration_result = udc_system.register_rsu(rsu_name, rsu_timestamp)
    print(rsu_registration_result)
# Out:
# EV1 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBAOjS/35r803zvzDU/Hbz9+6fdwXSHz27
# albWHY+T4xhBV0L/mFgPjRnFN0FQfbMDXy+nlZUdWl76w9baiv1eAOkCAwEAAQ==
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIBVQIBADANBgkqhkiG9w0BAQEFAASCAT8wggE7AgEAAkEA6NL/fmvzTfO/MNT8
# dvP37p93BdIfPbtqVtYdj5PjGEFXQv+YWA+NGcU3QVB9swNfL6eVlR1aXvrD1tqK
# /V4A6QIDAQABAkBDm9nzhTd/AHQZow+5Hzl1AruWZiEKVR0ZIE4vPluo0+rCrgtb
# GLm+lAsFtCsnwruTR15ClX61FQ6JfTCk9p8BAiEA+s3hZ1YW+a+CxEPK4TPbnOtg
# KDhMPgNoxOtrZiC8YCECIQDtpcMVFHrAHHGychCw0r7zrL73LR7KZuZbU2SRsqGn
# yQIgAgVGm56F8N0JIKurJsVUL5911t0dQCKm5W9AHkKFQgECIQDFdXPwsgGEWp4F
# /Uzs/072PVS3IGBzIKjKvTHU9a3oMQIhAKrFniGbJXMaioHptGR/lo0Ry26QzEjY
# 8P14L3drrQqH
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: ac68d11c9eadc65fad5f862a5e201d74a9ae26c72cfb681225f38e0ae46b538f
# EV2 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBAJXYTyitxZ+QX45lNajXmYPxoTl8BMX+
# HLC/lVaOyjz9jbCrpLh+83TmD5Up30x1g3MVVhBa4DV6J3TJWO18Fh8CAwEAAQ==
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIBVwIBADANBgkqhkiG9w0BAQEFAASCAUEwggE9AgEAAkEAldhPKK3Fn5BfjmU1
# qNeZg/GhOXwExf4csL+VVo7KPP2NsKukuH7zdOYPlSnfTHWDcxVWEFrgNXondMlY
# 7XwWHwIDAQABAkEAg0ioWiCds+ZfAjhEYjC7TLHIKsAwwnOYGXdRVSv3nqTEav8G
# RK7UILYfNsZNs1xVDQBeU6LORJ1RgbLJodHf4QIhAMRRvBis6iz2p+hB0RJFesCs
# b2L944fed6Z+XmmeW2zPAiEAw2XHCU6L9RcqqoHUEzWUQ3ssdITVeO8LgBj5UGcR
# NbECIQCy3sXCtcmnrhTOSSl0vFlbs8DJMQpegRQDXqAnG2GxgQIhALdIptSCCyJR
# IsJhma6TGYna5i4904fmoqD7zBCxPSFhAiEAn3bgftTJp7Z0C4GqLBJX0edXlizY
# AbWRq99fRy8cgpg=
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 0856920398157fe10a86d32cccf4a43f62c1bc73d25738466d39aa1164aa3673
# EV3 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBANkm2bgDURQe++lKVWzlIDw6SwGRRZLW
# /9+YV30IWjQsPGCU76R+No58xSqDEaMydHPxl6lz7lVLEUEnXzcYHDsCAwEAAQ==
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIBVQIBADANBgkqhkiG9w0BAQEFAASCAT8wggE7AgEAAkEA2SbZuANRFB776UpV
# bOUgPDpLAZFFktb/35hXfQhaNCw8YJTvpH42jnzFKoMRozJ0c/GXqXPuVUsRQSdf
# NxgcOwIDAQABAkEA16n+EQM6QwGCru9kaAInQamjVKsyreNZvHdQbJ0e+TAhYyWW
# HhsrlKbrc72ynZPwfV+kxkSpzOJgIOixz978AQIhAO+InnYnHf5tGDAoLiWeYbTx
# oTnanUKPe/L7Alg8ZQvTAiEA6BRZLPO+ErALuWdckw3aAaS8eNg9r/uhIMc+IC48
# dPkCIHg/WW1vDbugALiMMz5nWB2B/7IPcUrsxQihwfeRuhhJAiEAxa0/X+ilR6mn
# 8t41nhQ4UxoMZypZMOK2FgNfyW1YlZECIGDC/rxpbjjVPXNgzTuZmLaDVC3ujp7j
# qeXgVE5F+fPB
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 4a863a34f7a198e11d6ac1290c2698c31698a5630eef3b5eba7694843f5a4e0e
# CS1 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBAKyROwTtBlWycDFPYnmTXyPCCjqTwrmx
# szhrhyTWi6dnhaYS0sU0s8Pmi42r9ShxWRRoO3tcER5gdULqpeothqECAwEAAQ==
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIBVQIBADANBgkqhkiG9w0BAQEFAASCAT8wggE7AgEAAkEArJE7BO0GVbJwMU9i
# eZNfI8IKOpPCubGzOGuHJNaLp2eFphLSxTSzw+aLjav1KHFZFGg7e1wRHmB1Quql
# 6i2GoQIDAQABAkAzOupKjBNVXaPw/6A8d4PHGdPvj+4/MoICPenhBdBv4c7dAV5N
# R9/lL59HEA/qVnleRW5nYLsMGuT9yTlX70ABAiEA3DBjTaHw8JVPQBqNEO/ipAeH
# Sthd0saff27K0hA7860CIQDIohqHeKg4e9xJ41cCnENKQENMrb3KYmmT0dT/NFtd
# RQIgFdamwrhhETt91LnNa/Se4e3tOTskcxdIEneGnjcF+zECIQCBQqcS5rKCiZI4
# bGaPgPt9Z/+z9C/VpyfcG5E9xo6ifQIhAMUJMbQToGWdC2v+T0FswxZBO91XJVPR
# NzeHQ87oK1sY
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 05385b997e3dac687380d8e6e001effa8db680784bf4d0f59a763b03fe6d0ea3
# CS2 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBANmgdnmZRizOVkxDJtKbz8oi+RaRftDU
# XSYO0FlQVjV9I35GD0mvJLd5Uo6elw16Al8wR2saNT3IImhakznn7TsCAwEAAQ==
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIBVQIBADANBgkqhkiG9w0BAQEFAASCAT8wggE7AgEAAkEA2aB2eZlGLM5WTEMm
# 0pvPyiL5FpF+0NRdJg7QWVBWNX0jfkYPSa8kt3lSjp6XDXoCXzBHaxo1PcgiaFqT
# OeftOwIDAQABAkEAiyEk3PR6gqafUT4VEcv++bGGIUF/G67Ipk4OMStFEgfyfI95
# mMMDFp+dKAtndRg0Mb8Teyx802E8722ZKzAhIQIhAPgzmAN5k9whpyiXZBYwVoTw
# gXAufAnkrA+xY5dVNfrDAiEA4HbxBhrK3RY2vLUaEvomvrAzHc6AknZpx3V8ZmMd
# 7CkCIF0HWY7T3uu/YVwBgm4eqA8j5iAaDDvZDfTD1ERAl/7pAiEAqAqDYEWYj7E8
# o0OVVJWvgdxZODxLZtp9UFR1IBWd5hkCIG+KwubYFLEroY/P1iFbBbeLScfAzlxm
# EPs8qGuynVGB
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 8c30b03beacd4787befb2e652778aa8bce6f8718290f6e8f89bb21b855280788
# CS3 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBALEBuGAh8QexjniGbYg+sEZ0D7pn3Cww
# xA4o0VKuRIdQbS1os6O07Sook1CrnQFblzNG/6YdtHw6aluwWjJJxxsCAwEAAQ==
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIBUwIBADANBgkqhkiG9w0BAQEFAASCAT0wggE5AgEAAkEAsQG4YCHxB7GOeIZt
# iD6wRnQPumfcLDDEDijRUq5Eh1BtLWizo7TtKiiTUKudAVuXM0b/ph20fDpqW7Ba
# MknHGwIDAQABAj8MchKEr95CrDlYQBtzePTr/z0b3jGc6dDfLf+J0LcAzIjwoVEL
# 3h3aOId1MoRfvPreugKWQDhuuFgcAwL94kECIQDXxLTj/Iia+F1BjP+8jFjJZyKc
# at+gv1pOooXvUVkz0QIhANICzJtdcR1JcI85VuaN0xp6+2z+pF9aKmVCU1ybUKMr
# AiEAzUhJEd/h2A8UKpmLdkfQ8U0+kLLdsIJd2RKnetlalQECIEL+FZryIeU/yiJG
# HkyJrW/jD1Vjnbe1IZUPpVwDR6PlAiBKgg8eIo3/2QB8FBrW/7ja1ng7/5h0zQmj
# 1HlLDAKyBw==
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 44faec857a1be041909a1e0cd5c2117413953cf3737a9bfa69aec09ec4c34b47
# RSU1 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBALY3lpBDst6jtYZFhddb9YKbc/uNpkbI
# jmViJmE4RDbQx4Z8oTCg1YU/TJ1/d5dqKz5kaGTwsG9AnnN32z947S0CAwEAAQ==
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIBVAIBADANBgkqhkiG9w0BAQEFAASCAT4wggE6AgEAAkEAtjeWkEOy3qO1hkWF
# 11v1gptz+42mRsiOZWImYThENtDHhnyhMKDVhT9MnX93l2orPmRoZPCwb0Cec3fb
# P3jtLQIDAQABAkBPGf6QjfL+V48bxN5/SPphQl6tGybNn47BUERc+/IQ4QDet5fG
# Ay3SbzT3lY7g5dQIqTzEk5SV5XRTRnFSx7lBAiEA7yEvfUihJ/MkoD/8ff/YogPV
# C4t+dlTIKZJTQOIR92kCIQDDEogFNTHxlTnwRuKj3uZz/Q35HVNoEjW0omsW/1xz
# JQIgXVuFYNIkKKaiW/XfK4nhF4+Lc1BodOYwpxo7ao9YGFECIGTF7f7CvEpRDN1T
# wUFmpSbGU7GdtLjOr2/hd/EpelkBAiEA7woy9q00ROFYeV8GsM4IvNoWvfOgBOG0
# sQPARxABWIU=
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: ec9926df5f00035c5b759c3e04c3a1f92d441893fdcbe7d768767ca5fd65bb31
# RSU2 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBAKUBMhsVR/gDry5SJYaEToTV9hjDMHUo
# 1WQJCtxSPptSWqyF0QITjUm/0dPMJxySJuXi3GZq8gQbmF2OGl1Yoc8CAwEAAQ==
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIBVQIBADANBgkqhkiG9w0BAQEFAASCAT8wggE7AgEAAkEApQEyGxVH+AOvLlIl
# hoROhNX2GMMwdSjVZAkK3FI+m1JarIXRAhONSb/R08wnHJIm5eLcZmryBBuYXY4a
# XVihzwIDAQABAkBqojAwYntlI3Rluf64RO69V8y3ygSZ4m6tPE7BfYEqPG/b7yoB
# 8TR9HQ5H+RQBUQP/hAMC3FT4Pqd4ko7eAxVxAiEA0a5stFUxB/VDQQ6Rr32D5uQN
# JvstbW6B9CTtw9K7/ikCIQDJdEjpaW161DPFHXT0D9CCoC/XEa2Ft51OXuZGi1+v
# NwIhAJC13pP+j548aLQHiAgjidrZ3THf/BQgRlPnAKk7UT8xAiEAp0jlxtViMQ4H
# U1bLqGN9fQsxzsECO7imas7JH6lasm8CIEszaycIYHTwtUPFaU4o55OQHs9RzleO
# dGr6rRXK2uIv
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: aec359d705b1a1dfa1888c8c04ab2ce1076c18ea2d9b69b57c7a0d0abb70b8ac
# RSU3 registration successful.
# Public Key:
# -----BEGIN PUBLIC KEY-----
# MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBAKw2B3ub6P8ILzF9YF8HTMp7OolrQKl2
# lfCE5Q/EjnC2ZfUU72rtNd917krlxhNbQyYRY0blqHYIK7Hp4BZru3sCAwEAAQ==
# -----END PUBLIC KEY-----
#
# Private Key:
# -----BEGIN PRIVATE KEY-----
# MIIBVAIBADANBgkqhkiG9w0BAQEFAASCAT4wggE6AgEAAkEArDYHe5vo/wgvMX1g
# XwdMyns6iWtAqXaV8ITlD8SOcLZl9RTvau0133XuSuXGE1tDJhFjRuWodggrseng
# Fmu7ewIDAQABAkA4fXiy6Y/iqNKiT1hfk8ty2D15en85l7bTsSRaqcV33zMXT8eQ
# JvOUZf3lVs72B/ULFgwabyIXeY/HUARnUeLRAiEA4+9Wq/1HAPcVaTH0XjrFDIDT
# s9By4/pTeb+y+OczlAcCIQDBajyxaYXeFOsaSjXTb//BAUcH7xwwgZGZVWlHE4SH
# 7QIgWNn0dEjgA81NaFtTweOw6mXRoJeSIbJ0FdKXZpVhssMCICEc4w8slbKTujxi
# AB0Wy55rbZG6KgVT6W1q5f85JDNxAiEA2Nuo8RJ5GwsWuNbxV+RxmzDQdIgaquS7
# 038dcxK7QUw=
# -----END PRIVATE KEY-----
#
# Pseudo-Identity: 8645dfaad7300671a93f18f991caa58e54009ca59f317cae0192dec386500b26
