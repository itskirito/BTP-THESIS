# %% [markdown]
# WE WILL IMPLEMENT THE GRAPHS FOR DIFFERENT SIZES IF THE KEYS AND COMPARE THE RESULTS FOR COMOUTATIONAL ITERATIONS IT TAKES. HT EBASE ALGORITHM FOR HASHING IS SHA 1 USED HERE:

# %% [markdown]
# FOR 2048 BITS SIZE KEYS

# %%
import hashlib
import os
from cryptography.hazmat.primitives.asymmetric import rsa
from cryptography.hazmat.primitives import serialization
import time
import matplotlib.pyplot as plt


class UDC:
    def __init__(self):
        pass

    def register_ev(self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def register_cs(self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def register_rsu(self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def calculate_auth_ev_udc(self, public_key, pseudo_identity, t_ev):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha1(public_key_bytes + pseudo_identity.encode() + b'H0' + t_ev.encode()).hexdigest()

    def calculate_auth_cs_udc(self, public_key, pseudo_identity, t_cs):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha1(public_key_bytes + pseudo_identity.encode() + b'H0' + t_cs.encode()).hexdigest()

    def calculate_auth_rsu_udc(self, public_key, pseudo_identity, t_rsu):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha1(public_key_bytes + pseudo_identity.encode() + b'H0' + t_rsu.encode()).hexdigest()

    def calculate_pseudo_identity(self, private_key, unique_id):
        private_key_bytes = private_key.private_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PrivateFormat.PKCS8,
            encryption_algorithm=serialization.NoEncryption()
        )
        return hashlib.sha1(private_key_bytes + unique_id.encode()).hexdigest()

    def generate_key_pair(self):
        private_key = rsa.generate_private_key(
            public_exponent=65537,
            key_size=2048
        )
        public_key = private_key.public_key()

        return private_key, public_key


def compute_time(protocol_func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = protocol_func(*args, **kwargs)
        end_time = time.time()
        execution_time = (end_time - start_time) * 1000  # Convert to milliseconds
        return execution_time

    return wrapper


@compute_time
def run_protocol(udc):
    # Registration process for EVs
    ev_identity = "EV1"
    ev_public_key, ev_pseudo_identity = udc.register_ev(ev_identity)

    # Registration process for CSs
    cs_identity = "CS1"
    cs_public_key, cs_pseudo_identity = udc.register_cs(cs_identity)

    # Registration process for RSUs
    rsu_identity = "RSU1"
    rsu_public_key, rsu_pseudo_identity = udc.register_rsu(rsu_identity)

    # Authentication process
    t_ev = "Tst1"
    auth_ev_udc = udc.calculate_auth_ev_udc(ev_public_key, ev_pseudo_identity, t_ev)

    t_cs = "Tst2"
    auth_cs_udc = udc.calculate_auth_cs_udc(cs_public_key, cs_pseudo_identity, t_cs)

    t_rsu = "Tst3"
    auth_rsu_udc = udc.calculate_auth_rsu_udc(rsu_public_key, rsu_pseudo_identity, t_rsu)


def plot_computational_time(x_values, y_values):
    plt.plot(x_values, y_values)
    plt.xlabel('No. of Iterations')
    plt.ylabel('Computational Time (ms)')
    plt.title('Computational Time of the Authentication Scheme(2048 Bits)')
    plt.show()


def main():
    num_executions = 50
    x_values = list(range(1, num_executions + 1))
    y_values = []

    for _ in range(num_executions):
        udc = UDC()
        execution_time = run_protocol(udc)
        y_values.append(execution_time)

    plot_computational_time(x_values, y_values)


if __name__ == '__main__':
    main()

# %% [markdown]
# FOR 1024 BITS KEYS SIZE

# %%
import hashlib
import os
from cryptography.hazmat.primitives.asymmetric import rsa
from cryptography.hazmat.primitives import serialization
import time
import matplotlib.pyplot as plt


class UDC:
    def __init__(self):
        pass

    def register_ev(self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def register_cs(self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def register_rsu(self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def calculate_auth_ev_udc(self, public_key, pseudo_identity, t_ev):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha1(public_key_bytes + pseudo_identity.encode() + b'H0' + t_ev.encode()).hexdigest()

    def calculate_auth_cs_udc(self, public_key, pseudo_identity, t_cs):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha1(public_key_bytes + pseudo_identity.encode() + b'H0' + t_cs.encode()).hexdigest()

    def calculate_auth_rsu_udc(self, public_key, pseudo_identity, t_rsu):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha1(public_key_bytes + pseudo_identity.encode() + b'H0' + t_rsu.encode()).hexdigest()

    def calculate_pseudo_identity(self, private_key, unique_id):
        private_key_bytes = private_key.private_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PrivateFormat.PKCS8,
            encryption_algorithm=serialization.NoEncryption()
        )
        return hashlib.sha1(private_key_bytes + unique_id.encode()).hexdigest()

    def generate_key_pair(self):
        private_key = rsa.generate_private_key(
            public_exponent=65537,
            key_size=1024
        )
        public_key = private_key.public_key()

        return private_key, public_key


def compute_time(protocol_func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = protocol_func(*args, **kwargs)
        end_time = time.time()
        execution_time = (end_time - start_time) * 1000  # Convert to milliseconds
        return execution_time

    return wrapper


@compute_time
def run_protocol(udc):
    # Registration process for EVs
    ev_identity = "EV1"
    ev_public_key, ev_pseudo_identity = udc.register_ev(ev_identity)

    # Registration process for CSs
    cs_identity = "CS1"
    cs_public_key, cs_pseudo_identity = udc.register_cs(cs_identity)

    # Registration process for RSUs
    rsu_identity = "RSU1"
    rsu_public_key, rsu_pseudo_identity = udc.register_rsu(rsu_identity)

    # Authentication process
    t_ev = "Tst1"
    auth_ev_udc = udc.calculate_auth_ev_udc(ev_public_key, ev_pseudo_identity, t_ev)

    t_cs = "Tst2"
    auth_cs_udc = udc.calculate_auth_cs_udc(cs_public_key, cs_pseudo_identity, t_cs)

    t_rsu = "Tst3"
    auth_rsu_udc = udc.calculate_auth_rsu_udc(rsu_public_key, rsu_pseudo_identity, t_rsu)


def plot_computational_time(x_values, y_values):
    plt.plot(x_values, y_values)
    plt.xlabel('No. of Iterations')
    plt.ylabel('Computational Time (ms)')
    plt.title('Computational Time of the Authentication Scheme (1024 Bits)')
    plt.show()


def main():
    num_executions = 50
    x_values = list(range(1, num_executions + 1))
    y_values = []

    for _ in range(num_executions):
        udc = UDC()
        execution_time = run_protocol(udc)
        y_values.append(execution_time)

    plot_computational_time(x_values, y_values)


if __name__ == '__main__':
    main()

# %% [markdown]
# FOR 512 BITS KEYS SIZES

# %%
import hashlib
import os
from cryptography.hazmat.primitives.asymmetric import rsa
from cryptography.hazmat.primitives import serialization
import time
import matplotlib.pyplot as plt


class UDC:
    def __init__(self):
        pass

    def register_ev(self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def register_cs(self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def register_rsu(self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def calculate_auth_ev_udc(self, public_key, pseudo_identity, t_ev):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha1(public_key_bytes + pseudo_identity.encode() + b'H0' + t_ev.encode()).hexdigest()

    def calculate_auth_cs_udc(self, public_key, pseudo_identity, t_cs):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha1(public_key_bytes + pseudo_identity.encode() + b'H0' + t_cs.encode()).hexdigest()

    def calculate_auth_rsu_udc(self, public_key, pseudo_identity, t_rsu):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha1(public_key_bytes + pseudo_identity.encode() + b'H0' + t_rsu.encode()).hexdigest()

    def calculate_pseudo_identity(self, private_key, unique_id):
        private_key_bytes = private_key.private_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PrivateFormat.PKCS8,
            encryption_algorithm=serialization.NoEncryption()
        )
        return hashlib.sha1(private_key_bytes + unique_id.encode()).hexdigest()

    def generate_key_pair(self):
        private_key = rsa.generate_private_key(
            public_exponent=65537,
            key_size=512
        )
        public_key = private_key.public_key()

        return private_key, public_key


def compute_time(protocol_func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = protocol_func(*args, **kwargs)
        end_time = time.time()
        execution_time = (end_time - start_time) * 1000  # Convert to milliseconds
        return execution_time

    return wrapper


@compute_time
def run_protocol(udc):
    # Registration process for EVs
    ev_identity = "EV1"
    ev_public_key, ev_pseudo_identity = udc.register_ev(ev_identity)

    # Registration process for CSs
    cs_identity = "CS1"
    cs_public_key, cs_pseudo_identity = udc.register_cs(cs_identity)

    # Registration process for RSUs
    rsu_identity = "RSU1"
    rsu_public_key, rsu_pseudo_identity = udc.register_rsu(rsu_identity)

    # Authentication process
    t_ev = "Tst1"
    auth_ev_udc = udc.calculate_auth_ev_udc(ev_public_key, ev_pseudo_identity, t_ev)

    t_cs = "Tst2"
    auth_cs_udc = udc.calculate_auth_cs_udc(cs_public_key, cs_pseudo_identity, t_cs)

    t_rsu = "Tst3"
    auth_rsu_udc = udc.calculate_auth_rsu_udc(rsu_public_key, rsu_pseudo_identity, t_rsu)


def plot_computational_time(x_values, y_values):
    plt.plot(x_values, y_values)
    plt.xlabel('No. of Iterations')
    plt.ylabel('Computational Time (ms)')
    plt.title('Computational Time of the Authentication Scheme(512 Bits)')
    plt.show()


def main():
    num_executions = 50
    x_values = list(range(1, num_executions + 1))
    y_values = []

    for _ in range(num_executions):
        udc = UDC()
        execution_time = run_protocol(udc)
        y_values.append(execution_time)

    plot_computational_time(x_values, y_values)


if __name__ == '__main__':
    main()

# %%
import hashlib
import os
from cryptography.hazmat.primitives.asymmetric import rsa
from cryptography.hazmat.primitives import serialization
import time
import matplotlib.pyplot as plt


class UDC:
    def __init__(self):
        pass

    def register_ev(self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def register_cs(self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def register_rsu(self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def calculate_auth_ev_udc(self, public_key, pseudo_identity, t_ev):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha1(public_key_bytes + pseudo_identity.encode() + b'H0' + t_ev.encode()).hexdigest()

    def calculate_auth_cs_udc(self, public_key, pseudo_identity, t_cs):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha1(public_key_bytes + pseudo_identity.encode() + b'H0' + t_cs.encode()).hexdigest()

    def calculate_auth_rsu_udc(self, public_key, pseudo_identity, t_rsu):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha1(public_key_bytes + pseudo_identity.encode() + b'H0' + t_rsu.encode()).hexdigest()

    def calculate_pseudo_identity(self, private_key, unique_id):
        private_key_bytes = private_key.private_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PrivateFormat.PKCS8,
            encryption_algorithm=serialization.NoEncryption()
        )
        return hashlib.sha1(private_key_bytes + unique_id.encode()).hexdigest()

    def generate_key_pair(self):
        private_key = rsa.generate_private_key(
            public_exponent=65537,
            key_size=512
        )
        public_key = private_key.public_key()

        return private_key, public_key


def compute_time(protocol_func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = protocol_func(*args, **kwargs)
        end_time = time.time()
        execution_time = (end_time - start_time) * 1000  # Convert to milliseconds
        return execution_time

    return wrapper


@compute_time
def run_protocol(udc):
    # Registration process for EVs
    ev_identity = "EV1"
    ev_public_key, ev_pseudo_identity = udc.register_ev(ev_identity)

    # Registration process for CSs
    cs_identity = "CS1"
    cs_public_key, cs_pseudo_identity = udc.register_cs(cs_identity)

    # Registration process for RSUs
    rsu_identity = "RSU1"
    rsu_public_key, rsu_pseudo_identity = udc.register_rsu(rsu_identity)

    # Authentication process
    t_ev = "Tst1"
    auth_ev_udc = udc.calculate_auth_ev_udc(ev_public_key, ev_pseudo_identity, t_ev)

    t_cs = "Tst2"
    auth_cs_udc = udc.calculate_auth_cs_udc(cs_public_key, cs_pseudo_identity, t_cs)

    t_rsu = "Tst3"
    auth_rsu_udc = udc.calculate_auth_rsu_udc(rsu_public_key, rsu_pseudo_identity, t_rsu)


def plot_computational_time(x_values, y_values):
    plt.plot(x_values, y_values)
    plt.xlabel('No. of Executions')
    plt.ylabel('Computational Time (ms)')
    plt.title('Computational Time of the Authentication Scheme (512 Bits)')
    plt.show()


def main():
    num_executions = 50
    x_values = list(range(1, num_executions + 1))
    y_values = []

    for iteration in range(num_executions):
        udc = UDC()
        execution_time = run_protocol(udc)
        y_values.append(execution_time)
        print(f"Iteration: {iteration + 1}, Execution Time: {execution_time:.2f} ms")

    plot_computational_time(x_values, y_values)


if __name__ == '__main__':
    main()
# Out:
# Iteration: 1, Execution Time: 157.21 ms
# Iteration: 2, Execution Time: 30.47 ms
# Iteration: 3, Execution Time: 36.69 ms
# Iteration: 4, Execution Time: 35.92 ms
# Iteration: 5, Execution Time: 30.08 ms
# Iteration: 6, Execution Time: 87.99 ms
# Iteration: 7, Execution Time: 33.73 ms
# Iteration: 8, Execution Time: 28.18 ms
# Iteration: 9, Execution Time: 25.53 ms
# Iteration: 10, Execution Time: 26.36 ms
# Iteration: 11, Execution Time: 47.58 ms
# Iteration: 12, Execution Time: 50.83 ms
# Iteration: 13, Execution Time: 60.27 ms
# Iteration: 14, Execution Time: 36.59 ms
# Iteration: 15, Execution Time: 26.24 ms
# Iteration: 16, Execution Time: 84.88 ms
# Iteration: 17, Execution Time: 24.19 ms
# Iteration: 18, Execution Time: 34.41 ms
# Iteration: 19, Execution Time: 22.98 ms
# Iteration: 20, Execution Time: 22.20 ms
# Iteration: 21, Execution Time: 54.87 ms
# Iteration: 22, Execution Time: 47.23 ms
# Iteration: 23, Execution Time: 32.42 ms
# Iteration: 24, Execution Time: 24.50 ms
# Iteration: 25, Execution Time: 23.13 ms
# Iteration: 26, Execution Time: 20.96 ms
# Iteration: 27, Execution Time: 23.58 ms
# Iteration: 28, Execution Time: 39.97 ms
ms
# Iteration: 47, Key Size: 2048 bits, Execution Time: 109.87 ms
# Iteration: 48, Key Size: 2048 bits, Execution Time: 186.85 ms
# Iteration: 49, Key Size: 2048 bits, Execution Time: 187.27 ms
# Iteration: 50, Key Size: 2048 bits, Execution Time: 297.46 ms

# %% [markdown]
# NOW, WE WILL BE USING SHA-256 INSTEAD OF THE SHA-1 (THATS ORIGINALLY USED IN THE PROTOCOL) AND SEE THE RESULTS.

# %%
import hashlib
import os
from cryptography.hazmat.primitives.asymmetric import rsa
from cryptography.hazmat.primitives import serialization
import time
import matplotlib.pyplot as plt


class UDC:
    def __init__(self):
        pass

    def register_ev(self, identity, key_size):
        private_key, public_key = self.generate_key_pair(key_size)
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def register_cs(self, identity, key_size):
        private_key, public_key = self.generate_key_pair(key_size)
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def register_rsu(self, identity, key_size):
        private_key, public_key = self.generate_key_pair(key_size)
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def calculate_auth_ev_udc(self, public_key, pseudo_identity, t_ev):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha256(public_key_bytes + pseudo_identity.encode() + b'H0' + t_ev.encode()).hexdigest()

    def calculate_auth_cs_udc(self, public_key, pseudo_identity, t_cs):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha256(public_key_bytes + pseudo_identity.encode() + b'H0' + t_cs.encode()).hexdigest()

    def calculate_auth_rsu_udc(self, public_key, pseudo_identity, t_rsu):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha256(public_key_bytes + pseudo_identity.encode() + b'H0' + t_rsu.encode()).hexdigest()

    def calculate_pseudo_identity(self, private_key, unique_id):
        private_key_bytes = private_key.private_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PrivateFormat.PKCS8,
            encryption_algorithm=serialization.NoEncryption()
        )
        return hashlib.sha256(private_key_bytes + unique_id.encode()).hexdigest()

    def generate_key_pair(self, key_size):
        private_key = rsa.generate_private_key(
            public_exponent=65537,
            key_size=key_size
        )
        public_key = private_key.public_key()

        return private_key, public_key


def compute_time(protocol_func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = protocol_func(*args, **kwargs)
        end_time = time.time()
        execution_time = (end_time - start_time) * 1000  # Convert to milliseconds
        return execution_time

    return wrapper


@compute_time
def run_protocol(udc, key_size):
    # Registration process for EVs
    ev_identity = "EV1"
    ev_public_key, ev_pseudo_identity = udc.register_ev(ev_identity, key_size)

    # Registration process for CSs
    cs_identity = "CS1"
    cs_public_key, cs_pseudo_identity = udc.register_cs(cs_identity, key_size)

    # Registration process for RSUs
    rsu_identity = "RSU1"
    rsu_public_key, rsu_pseudo_identity = udc.register_rsu(rsu_identity, key_size)

    # Authentication process
    t_ev = "Tst1"
    auth_ev_udc = udc.calculate_auth_ev_udc(ev_public_key, ev_pseudo_identity, t_ev)

    t_cs = "Tst2"
    auth_cs_udc = udc.calculate_auth_cs_udc(cs_public_key, cs_pseudo_identity, t_cs)

    t_rsu = "Tst3"
    auth_rsu_udc = udc.calculate_auth_rsu_udc(rsu_public_key, rsu_pseudo_identity, t_rsu)


def plot_computational_time(x_values, y_values, key_sizes):
    for i, key_size in enumerate(key_sizes):
        plt.plot(x_values, y_values[i], label=f'{key_size} bits')

    plt.xlabel('Protocol Execution')
    plt.ylabel('Computational Time (ms)')
    plt.title('Computational Time of the Authentication Protocol (SHA-256)')
    plt.legend()
    plt.show()


def main():
    key_sizes = [512, 1024, 2048]
    num_executions = 50

    x_values = list(range(1, num_executions + 1))
    y_values = [[] for _ in key_sizes]

    for i, key_size in enumerate(key_sizes):
        udc = UDC()
        for iteration in range(num_executions):
            execution_time = run_protocol(udc, key_size)
            y_values[i].append(execution_time)
            print(f"Iteration: {iteration + 1}, Key Size: {key_size} bits, Execution Time: {execution_time:.2f} ms")

    plot_computational_time(x_values, y_values, key_sizes)


if __name__ == '__main__':
    main()
# Out:
# Iteration: 1, Key Size: 512 bits, Execution Time: 24.21 ms
# Iteration: 2, Key Size: 512 bits, Execution Time: 13.92 ms
# Iteration: 3, Key Size: 512 bits, Execution Time: 18.19 ms
# Iteration: 4, Key Size: 512 bits, Execution Time: 14.39 ms
# Iteration: 5, Key Size: 512 bits, Execution Time: 17.57 ms
# Iteration: 6, Key Size: 512 bits, Execution Time: 18.68 ms
# Iteration: 7, Key Size: 512 bits, Execution Time: 13.72 ms
# Iteration: 8, Key Size: 512 bits, Execution Time: 13.44 ms
# Iteration: 9, Key Size: 512 bits, Execution Time: 13.78 ms
# Iteration: 10, Key Size: 512 bits, Execution Time: 13.50 ms
# Iteration: 11, Key Size: 512 bits, Execution Time: 14.14 ms
# Iteration: 12, Key Size: 512 bits, Execution Time: 17.00 ms
# Iteration: 13, Key Size: 512 bits, Execution Time: 13.17 ms
# Iteration: 14, Key Size: 512 bits, Execution Time: 13.04 ms
# Iteration: 15, Key Size: 512 bits, Execution Time: 17.66 ms
# Iteration: 16, Key Size: 512 bits, Execution Time: 14.18 ms
# Iteration: 17, Key Size: 512 bits, Execution Time: 11.26 ms
# Iteration: 18, Key Size: 512 bits, Execution Time: 11.79 ms
# Iteration: 19, Key Size: 512 bits, Execution Time: 14.39 ms
# Iteration: 20, Key Size: 512 bits, Execution Time: 18.94 ms
# Iteration: 21, Key Size: 512 bits, Execution Time: 12.99 ms
# Iteration: 22, Key Size: 512 bits, Execution Time: 12.10 ms
# Iteration: 23, Key Size: 512 bits, Execution Time: 12.86 ms
# Iteration: 24, Key Size: 512 bits, Execution Time: 14.67 ms
# Iteration: 25, Key Size: 512 bits, Execution Time: 14.01 ms
# Iteration: 26, Key Size: 512 bits, Execution Time: 12.45 ms
# Iteration: 27, Key Size: 512 bits, Execution Time: 18.17 ms
# Iteration: 28, Key Size: 512 bits, Execution Time: 16.42 ms
# Iteration: 29, Key Size: 512 bits, Execution Time: 12.65 ms
# Iteration: 30, Key Size: 512 bits, Execution Time: 17.17 ms
# Iteration: 31, Key Size: 512 bits, Execution Time: 13.96 ms
# Iteration: 32, Key Size: 512 bits, Execution Time: 14.41 ms
# Iteration: 33, Key Size: 512 bits, Execution Time: 13.39 ms
# Iteration: 34, Key Size: 512 bits, Execution Time: 13.08 ms
# Iteration: 35, Key Size: 512 bits, Execution Time: 14.43 ms
# Iteration: 36, Key Size: 512 bits, Execution Time: 13.15 ms
# Iteration: 37, Key Size: 512 bits, Execution Time: 11.71 ms
# Iteration: 38, Key Size: 512 bits, Execution Time: 14.93 ms
# Iteration: 39, Key Size: 512 bits, Execution Time: 13.36 ms
# Iteration: 40, Key Size: 512 bits, Execution Time: 13.20 ms
# Iteration: 41, Key Size: 512 bits, Execution Time: 13.75 ms
# Iteration: 42, Key Size: 512 bits, Execution Time: 14.64 ms
# Iteration: 43, Key Size: 512 bits, Execution Time: 14.11 ms
# Iteration: 44, Key Size: 512 bits, Execution Time: 13.94 ms
# Iteration: 45, Key Size: 512 bits, Execution Time: 16.20 ms
# Iteration: 46, Key Size: 512 bits, Execution Time: 14.53 ms
# Iteration: 47, Key Size: 512 bits, Execution Time: 15.76 ms
# Iteration: 48, Key Size: 512 bits, Execution Time: 14.10 ms
# Iteration: 49, Key Size: 512 bits, Execution Time: 14.68 ms
# Iteration: 50, Key Size: 512 bits, Execution Time: 15.89 ms
# Iteration: 1, Key Size: 1024 bits, Execution Time: 29.59 ms
# Iteration: 2, Key Size: 1024 bits, Execution Time: 35.20 ms
# Iteration: 3, Key Size: 1024 bits, Execution Time: 47.34 ms
# Iteration: 4, Key Size: 1024 bits, Execution Time: 32.99 ms
# Iteration: 5, Key Size: 1024 bits, Execution Time: 24.46 ms
# Iteration: 6, Key Size: 1024 bits, Execution Time: 37.57 ms
# Iteration: 7, Key Size: 1024 bits, Execution Time: 62.45 ms
# Iteration: 8, Key Size: 1024 bits, Execution Time: 65.10 ms
# Iteration: 9, Key Size: 1024 bits, Execution Time: 57.67 ms
# Iteration: 10, Key Size: 1024 bits, Execution Time: 55.97 ms
# Iteration: 11, Key Size: 1024 bits, Execution Time: 65.99 ms
# Iteration: 12, Key Size: 1024 bits, Execution Time: 61.35 ms
# Iteration: 13, Key Size: 1024 bits, Execution Time: 69.46 ms
# Iteration: 14, Key Size: 1024 bits, Execution Time: 52.74 ms
# Iteration: 15, Key Size: 1024 bits, Execution Time: 55.34 ms
# Iteration: 16, Key Size: 1024 bits, Execution Time: 53.84 ms
# Iteration: 17, Key Size: 1024 bits, Execution Time: 58.58 ms
self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def register_rsu(self, identity):
        private_key, public_key = self.generate_key_pair()
        pseudo_identity = self.calculate_pseudo_identity(private_key, identity)
        return public_key, pseudo_identity

    def calculate_auth_ev_udc(self, public_key, pseudo_identity, t_ev):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha256(public_key_bytes + pseudo_identity.encode() + b'H0' + t_ev.encode()).hexdigest()

    def calculate_auth_cs_udc(self, public_key, pseudo_identity, t_cs):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha256(public_key_bytes + pseudo_identity.encode() + b'H0' + t_cs.encode()).hexdigest()

    def calculate_auth_rsu_udc(self, public_key, pseudo_identity, t_rsu):
        public_key_bytes = public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        )
        return hashlib.sha256(public_key_bytes + pseudo_identity.encode() + b'H0' + t_rsu.encode()).hexdigest()

    def calculate_pseudo_identity(self, private_key, unique_id):
        private_key_bytes = private_key.private_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PrivateFormat.PKCS8,
            encryption_algorithm=serialization.NoEncryption()
        )
        return hashlib.sha256(private_key_bytes + unique_id.encode()).hexdigest()

    def generate_key_pair(self):
        private_key = rsa.generate_private_key(
            public_exponent=65537,
            key_size=self.key_size
        )
        public_key = private_key.public_key()

        return private_key, public_key


def compute_time(protocol_func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = protocol_func(*args, **kwargs)
        end_time = time.time()
        execution_time = (end_time - start_time) * 1000  # Convert to milliseconds
        return execution_time

    return wrapper


@compute_time
def run_protocol(udc, num_evs, num_css, num_rsus):
    # Registration process for EVs
    ev_identities = ["EV" + str(i) for i in range(1, num_evs + 1)]
    ev_public_keys = []
    ev_pseudo_identities = []
    for ev_identity in ev_identities:
        ev_public_key, ev_pseudo_identity = udc.register_ev(ev_identity)
        ev_public_keys.append(ev_public_key)
        ev_pseudo_identities.append(ev_pseudo_identity)

    # Registration process for CSs
    cs_identities = ["CS" + str(i) for i in range(1, num_css + 1)]
    cs_public_keys = []
    cs_pseudo_identities = []
    for cs_identity in cs_identities:
        cs_public_key, cs_pseudo_identity = udc.register_cs(cs_identity)
        cs_public_keys.append(cs_public_key)
        cs_pseudo_identities.append(cs_pseudo_identity)

    # Registration process for RSUs
    rsu_identities = ["RSU" + str(i) for i in range(1, num_rsus + 1)]
    rsu_public_keys = []
    rsu_pseudo_identities = []
    for rsu_identity in rsu_identities:
        rsu_public_key, rsu_pseudo_identity = udc.register_rsu(rsu_identity)
        rsu_public_keys.append(rsu_public_key)
        rsu_pseudo_identities.append(rsu_pseudo_identity)

    # Authentication process
    t_ev = "Tst1"
    auth_ev_udc = []
    for ev_public_key, ev_pseudo_identity in zip(ev_public_keys, ev_pseudo_identities):
        auth_ev_udc.append(udc.calculate_auth_ev_udc(ev_public_key, ev_pseudo_identity, t_ev))

    t_cs = "Tst2"
    auth_cs_udc = []
    for cs_public_key, cs_pseudo_identity in zip(cs_public_keys, cs_pseudo_identities):
        auth_cs_udc.append(udc.calculate_auth_cs_udc(cs_public_key, cs_pseudo_identity, t_cs))

    t_rsu = "Tst3"
    auth_rsu_udc = []
    for rsu_public_key, rsu_pseudo_identity in zip(rsu_public_keys, rsu_pseudo_identities):
        auth_rsu_udc.append(udc.calculate_auth_rsu_udc(rsu_public_key, rsu_pseudo_identity, t_rsu))


def plot_computational_time(x_values, y_values, xlabel, ylabel, title):
    plt.plot(x_values, y_values)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()


def main():
    num_executions = 10
    num_evs_values = [1, 2, 3, 4, 5]  # Number of EVs to test
    num_css_values = [1, 2, 3, 4, 5]  # Number of CSs to test
    num_rsus_values = [1, 2, 3, 4, 5]  # Number of RSUs to test

    for num_evs in num_evs_values:
        for num_css in num_css_values:
            for num_rsus in num_rsus_values:
                x_values = [num_evs, num_css, num_rsus]
                y_values = []

                for _ in range(num_executions):
                    udc = UDC(key_size=512)  # Set the desired key size
                    execution_time = run_protocol(udc, num_evs, num_css, num_rsus)
                    y_values.append(execution_time)

                average_execution_time = sum(y_values) / num_executions
                print(f"Avg. Execution Time - EVs: {num_evs}, CSs: {num_css}, RSUs: {num_rsus} - {average_execution_time} ms")

                # Uncomment the following line to plot the graph for each combination of EVs, CSs, RSUs
                # plot_computational_time(x_values, y_values, 'Number of Entities', 'Computational Time (ms)', 'Computational Time vs. Number of Entities')


if __name__ == "__main__":
    main()
# Out:
# Avg. Execution Time - EVs: 1, CSs: 1, RSUs: 1 - 25.760769844055176 ms
# Avg. Execution Time - EVs: 1, CSs: 1, RSUs: 2 - 34.48538780212402 ms
# Avg. Execution Time - EVs: 1, CSs: 1, RSUs: 3 - 43.74067783355713 ms
# Avg. Execution Time - EVs: 1, CSs: 1, RSUs: 4 - 30.985307693481445 ms
# Avg. Execution Time - EVs: 1, CSs: 1, RSUs: 5 - 35.519981384277344 ms
# Avg. Execution Time - EVs: 1, CSs: 2, RSUs: 1 - 18.887042999267578 ms
# Avg. Execution Time - EVs: 1, CSs: 2, RSUs: 2 - 26.362037658691406 ms
# Avg. Execution Time - EVs: 1, CSs: 2, RSUs: 3 - 30.883479118347168 ms
# Avg. Execution Time - EVs: 1, CSs: 2, RSUs: 4 - 34.07633304595947 ms
# Avg. Execution Time - EVs: 1, CSs: 2, RSUs: 5 - 39.99030590057373 ms
# Avg. Execution Time - EVs: 1, CSs: 3, RSUs: 1 - 25.55701732635498 ms
# Avg. Execution Time - EVs: 1, CSs: 3, RSUs: 2 - 29.83841896057129 ms
# Avg. Execution Time - EVs: 1, CSs: 3, RSUs: 3 - 34.542059898376465 ms
# Avg. Execution Time - EVs: 1, CSs: 3, RSUs: 4 - 39.995551109313965 ms
# Avg. Execution Time - EVs: 1, CSs: 3, RSUs: 5 - 42.09144115447998 ms
# Avg. Execution Time - EVs: 1, CSs: 4, RSUs: 1 - 30.76488971710205 ms
# Avg. Execution Time - EVs: 1, CSs: 4, RSUs: 2 - 32.782959938049316 ms
# Avg. Execution Time - EVs: 1, CSs: 4, RSUs: 3 - 38.12215328216553 ms
# Avg. Execution Time - EVs: 1, CSs: 4, RSUs: 4 - 42.72313117980957 ms
# Avg. Execution Time - EVs: 1, CSs: 4, RSUs: 5 - 56.86798095703125 ms
# Avg. Execution Time - EVs: 1, CSs: 5, RSUs: 1 - 34.506869316101074 ms
# Avg. Execution Time - EVs: 1, CSs: 5, RSUs: 2 - 38.39397430419922 ms
# Avg. Execution Time - EVs: 1, CSs: 5, RSUs: 3 - 46.41377925872803 ms
# Avg. Execution Time - EVs: 1, CSs: 5, RSUs: 4 - 48.121094703674316 ms
# Avg. Execution Time - EVs: 1, CSs: 5, RSUs: 5 - 54.175615310668945 ms
# Avg. Execution Time - EVs: 2, CSs: 1, RSUs: 1 - 19.598674774169922 ms
# Avg. Execution Time - EVs: 2, CSs: 1, RSUs: 2 - 25.234365463256836 ms
# Avg. Execution Time - EVs: 2, CSs: 1, RSUs: 3 - 29.082059860229492 ms
# Avg. Execution Time - EVs: 2, CSs: 1, RSUs: 4 - 35.841917991638184 ms
# Avg. Execution Time - EVs: 2, CSs: 1, RSUs: 5 - 39.61894512176514 ms
# Avg. Execution Time - EVs: 2, CSs: 2, RSUs: 1 - 25.229406356811523 ms
# Avg. Execution Time - EVs: 2, CSs: 2, RSUs: 2 - 36.756181716918945 ms
# Avg. Execution Time - EVs: 2, CSs: 2, RSUs: 3 - 59.40442085266113 ms
# Avg. Execution Time - EVs: 2, CSs: 2, RSUs: 4 - 69.35510635375977 ms
# Avg. Execution Time - EVs: 2, CSs: 2, RSUs: 5 - 77.72259712219238 ms
# Avg. Execution Time - EVs: 2, CSs: 3, RSUs: 1 - 51.68132781982422 ms
# Avg. Execution Time - EVs: 2, CSs: 3, RSUs: 2 - 39.86845016479492 ms
# Avg. Execution Time - EVs: 2, CSs: 3, RSUs: 3 - 38.85016441345215 ms
# Avg. Execution Time - EVs: 2, CSs: 3, RSUs: 4 - 47.25441932678223 ms
# Avg. Execution Time - EVs: 2, CSs: 3, RSUs: 5 - 49.309468269348145 ms
# Avg. Execution Time - EVs: 2, CSs: 4, RSUs: 1 - 34.49568748474121 ms
# Avg. Execution Time - EVs: 2, CSs: 4, RSUs: 2 - 39.98570442199707 ms
# Avg. Execution Time - EVs: 2, CSs: 4, RSUs: 3 - 41.758012771606445 ms
# Avg. Execution Time - EVs: 2, CSs: 4, RSUs: 4 - 49.66402053833008 ms
# Avg. Execution Time - EVs: 2, CSs: 4, RSUs: 5 - 53.36005687713623 ms
# Avg. Execution Time - EVs: 2, CSs: 5, RSUs: 1 - 38.454532623291016 ms
# Avg. Execution Time - EVs: 2, CSs: 5, RSUs: 2 - 42.68355369567871 ms
# Avg. Execution Time - EVs: 2, CSs: 5, RSUs: 3 - 48.8461971282959 ms
# Avg. Execution Time - EVs: 2, CSs: 5, RSUs: 4 - 52.82695293426514 ms
# Avg. Execution Time - EVs: 2, CSs: 5, RSUs: 5 - 57.71636962890625 ms
# Avg. Execution Time - EVs: 3, CSs: 1, RSUs: 1 - 24.43211078643799 ms
# Avg. Execution Time - EVs: 3, CSs: 1, RSUs: 2 - 29.938101768493652 ms
# Avg. Execution Time - EVs: 3, CSs: 1, RSUs: 3 - 36.22691631317139 ms
# Avg. Execution Time - EVs: 3, CSs: 1, RSUs: 4 - 39.084577560424805 ms
# Avg. Execution Time - EVs: 3, CSs: 1, RSUs: 5 - 44.34049129486084 ms
# Avg. Execution Time - EVs: 3, CSs: 2, RSUs: 1 - 29.163146018981934 ms
# Avg. Execution Time - EVs: 3, CSs: 2, RSUs: 2 - 33.35447311401367 ms
# Avg. Execution Time - EVs: 3, CSs: 2, RSUs: 3 - 39.116859436035156 ms
# Avg. Execution Time - EVs: 3, CSs: 2, RSUs: 4 - 42.533087730407715 ms
# Avg. Execution Time - EVs: 3, CSs: 2, RSUs: 5 - 47.16079235076904 ms
# Avg. Execution Time - EVs: 3, CSs: 3, RSUs: 1 - 50.92966556549072 ms
# Avg. Execution Time - EVs: 3, CSs: 3, RSUs: 2 - 70.77136039733887 ms
# Avg. Execution Time - EVs: 3, CSs: 3, RSUs: 3 - 79.17206287384033 ms
# Avg. Execution Time - EVs: 3, CSs: 3, RSUs: 4 - 86.01558208465576 ms
# Avg. Execution Time - EVs: 3, CSs: 3, RSUs: 5 - 58.95693302154541 ms
# Avg. Execution Time - EVs: 3, CSs: 4, RSUs: 1 - 39.2009973526001 ms
# Avg. Execution Time - EVs: 3, CSs: 4, RSUs: 2 - 44.16630268096924 ms
# Avg. Execution Time - EVs: 3, CSs: 4, RSUs: 3 - 46.115994453430176 ms
# Avg. Execution Time - EVs: 3, CSs: 4, RSUs: 4 - 55.35225868225098 ms
# Avg. Execution Time - EVs: 3, CSs: 4, RSUs: 5 - 56.536030769348145 ms
# Avg. Execution Time - EVs: 3, CSs: 5, RSUs: 1 - 45.09096145629883 ms
# Avg. Execution Time - EVs: 3, CSs: 5, RSUs: 2 - 49.02215003967285 ms
# Avg. Execution Time - EVs: 3, CSs: 5, RSUs: 3 - 53.03020477294922 ms
# Avg. Execution Time - EVs: 3, CSs: 5, RSUs: 4 - 57.572150230407715 ms
# Avg. Execution Time - EVs: 3, CSs: 5, RSUs: 5 - 63.77875804901123 ms
# Avg. Execution Time - EVs: 4, CSs: 1, RSUs: 1 - 29.823803901672363 ms
# Avg. Execution Time - EVs: 4, CSs: 1, RSUs: 2 - 33.86986255645752 ms
# Avg. Execution Time - EVs: 4, CSs: 1, RSUs: 3 - 39.536380767822266 ms
# Avg. Execution Time - EVs: 4, CSs: 1, RSUs: 4 - 43.31517219543457 ms
# Avg. Execution Time - EVs: 4, CSs: 1, RSUs: 5 - 49.89304542541504 ms
# Avg. Execution Time - EVs: 4, CSs: 2, RSUs: 1 - 34.49599742889404 ms
# Avg. Execution Time - EVs: 4, CSs: 2, RSUs: 2 - 39.67845439910889 ms
# Avg. Execution Time - EVs: 4, CSs: 2, RSUs: 3 - 44.139981269836426 ms
# Avg. Execution Time - EVs: 4, CSs: 2, RSUs: 4 - 46.53124809265137 ms
# Avg. Execution Time - EVs: 4, CSs: 2, RSUs: 5 - 52.98769474029541 ms
# Avg. Execution Time - EVs: 4, CSs: 3, RSUs: 1 - 49.1969108581543 ms
# Avg. Execution Time - EVs: 4, CSs: 3, RSUs: 2 - 84.14247035980225 ms
# Avg. Execution Time - EVs: 4, CSs: 3, RSUs: 3 - 87.77360916137695 ms
# Avg. Execution Time - EVs: 4, CSs: 3, RSUs: 4 - 93.4854507446289 ms
# Avg. Execution Time - EVs: 4, CSs: 3, RSUs: 5 - 59.49139595031738 ms
# Avg. Execution Time - EVs: 4, CSs: 4, RSUs: 1 - 43.990373611450195 ms
# Avg. Execution Time - EVs: 4, CSs: 4, RSUs: 2 - 48.33364486694336 ms
# Avg. Execution Time - EVs: 4, CSs: 4, RSUs: 3 - 52.010250091552734 ms
# Avg. Execution Time - EVs: 4, CSs: 4, RSUs: 4 - 56.95347785949707 ms
# Avg. Execution Time - EVs: 4, CSs: 4, RSUs: 5 - 64.59851264953613 ms
# Avg. Execution Time - EVs: 4, CSs: 5, RSUs: 1 - 47.698020935058594 ms
# Avg. Execution Time - EVs: 4, CSs: 5, RSUs: 2 - 56.69889450073242 ms
# Avg. Execution Time - EVs: 4, CSs: 5, RSUs: 3 - 61.075568199157715 ms
# Avg. Execution Time - EVs: 4, CSs: 5, RSUs: 4 - 64.22371864318848 ms
# Avg. Execution Time - EVs: 4, CSs: 5, RSUs: 5 - 70.11032104492188 ms
# Avg. Execution Time - EVs: 5, CSs: 1, RSUs: 1 - 34.0869665145874 ms
# Avg. Execution Time - EVs: 5, CSs: 1, RSUs: 2 - 40.636301040649414 ms
# Avg. Execution Time - EVs: 5, CSs: 1, RSUs: 3 - 43.56718063354492 ms
# Avg. Execution Time - EVs: 5, CSs: 1, RSUs: 4 - 48.119258880615234 ms
# Avg. Execution Time - EVs: 5, CSs: 1, RSUs: 5 - 54.17375564575195 ms
# Avg. Execution Time - EVs: 5, CSs: 2, RSUs: 1 - 37.34445571899414 ms
# Avg. Execution Time - EVs: 5, CSs: 2, RSUs: 2 - 43.86093616485596 ms
# Avg. Execution Time - EVs: 5, CSs: 2, RSUs: 3 - 49.602627754211426 ms
# Avg. Execution Time - EVs: 5, CSs: 2, RSUs: 4 - 72.97518253326416 ms
# Avg. Execution Time - EVs: 5, CSs: 2, RSUs: 5 - 105.17737865447998 ms
# Avg. Execution Time - EVs: 5, CSs: 3, RSUs: 1 - 75.60441493988037 ms
# Avg. Execution Time - EVs: 5, CSs: 3, RSUs: 2 - 69.94938850402832 ms
# Avg. Execution Time - EVs: 5, CSs: 3, RSUs: 3 - 52.6392936706543 ms
# Avg. Execution Time - EVs: 5, CSs: 3, RSUs: 4 - 57.28933811187744 ms
# Avg. Execution Time - EVs: 5, CSs: 3, RSUs: 5 - 62.430429458618164 ms
# Avg. Execution Time - EVs: 5, CSs: 4, RSUs: 1 - 49.20549392700195 ms
# Avg. Execution Time - EVs: 5, CSs: 4, RSUs: 2 - 52.86846160888672 ms
# Avg. Execution Time - EVs: 5, CSs: 4, RSUs: 3 - 59.18629169464111 ms
# Avg. Execution Time - EVs: 5, CSs: 4, RSUs: 4 - 63.668227195739746 ms
# Avg. Execution Time - EVs: 5, CSs: 4, RSUs: 5 - 66.47975444793701 ms
# Avg. Execution Time - EVs: 5, CSs: 5, RSUs: 1 - 53.963494300842285 ms
# Avg. Execution Time - EVs: 5, CSs: 5, RSUs: 2 - 57.02695846557617 ms
# Avg. Execution Time - EVs: 5, CSs: 5, RSUs: 3 - 62.27521896362305 ms
# Avg. Execution Time - EVs: 5, CSs: 5, RSUs: 4 - 65.7383680343628 ms
# Avg. Execution Time - EVs: 5, CSs: 5, RSUs: 5 - 73.74060153961182 ms
